# %% [markdown]
# ### Raw data

# %%
"""Run all functions that load and cache data from remote."""

from build_dataset.workers import load_sensible_data as lsd


tc0 = {'hours': range(24),
    'days': range(7),
    'spans': [
        ("01/01/14", "31/12/14")
    ]
}
tc1 = {  # School weeks spring and fall 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("06/01/14", "24/01/14"),
        ("03/02/14", "13/04/14"),
        ("20/04/14", "16/05/14"),
        ("02/06/14", "20/06/14"),
        ("01/09/14", "13/10/14"),
        ("19/10/14", "05/12/14")
    ]
}
tc1_spring = {  # School weeks spring 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("06/01/14", "24/01/14"),
        ("03/02/14", "13/04/14"),
        ("20/04/14", "16/05/14"),
        ("02/06/14", "20/06/14"),
    ]
}
tc2 = {  # Exam weeks spring and fall 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("17/05/14", "01/06/14"),
        ("06/12/14", "21/12/14")
    ]
}
tc3 = {  # Holiday weeks spring and fall 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("01/01/14", "05/01/14"),
        ("25/01/14", "02/02/14"),
        ("14/04/14", "20/04/14"),
        ("21/06/14", "30/08/14"),
        ("13/10/14", "19/10/14"),
        ("22/12/14", "31/12/14")
    ]
}

for i, tc in enumerate([tc1_spring]): #enumerate([tc0, tc1, tc1_spring, tc2, tc3]):
    print "\n\n## ---------------- ##"
    print "## Building for tc%d ##" % i
    print "## ---------------- ##"

    print "\nLocation Reference..."
    print "\nsuccess!\n"
    print "Timezone Reference..."
    print "\nsuccess!\n"

    print "Iterating over datasets:"
    for dataset in ["calllog", "sms", "screen", "stop_locations", "bluetooth"]:
        print "\tBuilding '%s'...\t\t" % dataset,
        if dataset == "bluetooth":
            lsd.load(tc, dataset, filtering="bt_special", load_cached=True)
        else:
            pass
        print "\n\tsuccess!\n"
# Out:
#
#
# ## ---------------- ##
# ## Building for tc0 ##
# ## ---------------- ##
#
# Location Reference...
#
# success!
#
# Timezone Reference...
#
# success!
#
# Iterating over datasets:
# 	Building 'calllog'...
# 	success!
#
# 	Building 'sms'...
# 	success!
#
# 	Building 'screen'...
# 	success!
#
# 	Building 'stop_locations'...
# 	success!
#
# 	Building 'bluetooth'...
# 	success!

# %% [markdown]
# ### Records

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from collections import Counter
import os
from build_dataset.workers import load_sensible_data as lsd
from build_dataset.analysis import location_reference as locref

tc0 = {
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("01/01/14", "31/12/14")
    ]
}

location_reference_tc0 = locref.Load_location_reference(tc0).location_reference

df_call = lsd.load(tc0, "calllog")
df_text = lsd.load(tc0, "sms")
df_screen = lsd.load(tc0, "screen")
df_stops = lsd.load(tc0, "stop_locations")
df_physical = lsd.load(tc0, "bluetooth")

users = set(list(df_call['user'])) & set(list(df_text['user'])) & set(list(df_screen['user'])) & \
        set(list(df_stops['user'])) & set(list(df_physical['user']))
    
def call_timer(func):
    """Simple decorator to time function calls."""
    def wrapper(*args):
        print func.__name__,
        start = dt.now()
        output = func(*args)
        print "time:", dt.now() - start
        return output
    return wrapper
    
@call_timer
def _filter_call(df_u):
    df_u = df_u.drop('user', 1)
    df_u.loc[:, 'interaction'] = "call"
    df_u.loc[:, 'timestamp'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'timestamp']]
    df_u.loc[:, 'type'] = ["in" if t == 1 else "out" for t in df_u.loc[:, 'type']]
    df_u.columns = ["duration", "correspondent_id", "datetime", "direction", "interaction"]
    return df_u

@call_timer
def _filter_text(df_u):
    df_u = df_u[df_u.loc[:, 'status'] <= 0]
    df_u = df_u[df_u.loc[:, 'type'] <= 2]
    df_u = df_u.drop(['status','user'], 1)
    df_u.loc[:, 'interaction'] = 'text'
    df_u.loc[:, 'timestamp'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'timestamp']]
    df_u.loc[:, 'type'] = ["in" if t == 1 else "out" for t in df_u.loc[:, 'type']]
    df_u.columns = ["correspondent_id", "datetime", "direction", "interaction"]
    return df_u

@call_timer
def _filter_physical(u, df_u):
    df_u.loc[:, 'interaction'] = 'physical'
    df_u.loc[:, 'timestamp'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'timestamp']]
    df_u.loc[:, 'correspondent_id'] = [a if a != u else b 
                                for a,b in zip(df_u.loc[:, 'bt_mac'], df_u.loc[:, 'user'])]
    df_u = df_u.drop(['class','id','bt_mac','rssi', 'user'], 1)
    df_u.columns = ["datetime", "interaction", "correspondent_id"]
    return df_u

@call_timer
def _filter_screen(df_u):
    sessions = []
    i = 0
    for row in df_u.iterrows():
        event, times = row[1]['screen_on'], row[1]['timestamp']
        if i == 0:
            prev_event = event
            prev_times = times
            i+=1; continue
        elif event == 0 and prev_event == 1:
            duration = int(times-prev_times)
            sessions.append({'datetime': dt.fromtimestamp(prev_times), 
                             'duration': duration})
        prev_event = event
        prev_times = times
        i+=1
    df_u = pd.DataFrame(sessions)
    df_u.loc[:, 'interaction'] = 'screen'
    return df_u

@call_timer
def _filter_stops(u, df_u):
    def evaluate_event(r):
        user, label, arrival, departure = \
        r[1]['user'], r[1]['label'], r[1]['arrival'], r[1]['departure']
        
        state = location_reference_tc0[str(user)][str(label)]
        if state['type'] == "home":
            return "home"
        if state['type'] == "campus":
            if state['__friday_bar'] and dt.fromtimestamp(np.mean([arrival,departure])).hour >=17:
                return "friday_bar"
            return "campus"
        return "other"
        
    df_u.loc[:, 'duration'] = df_u.loc[:, 'departure'] - df_u.loc[:, 'arrival']
    df_u.loc[:, 'datetime'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'arrival']]
    df_u.loc[:, 'position'] = ["%d_%s" % (u, l) for l in df_u.loc[:, 'label']]
    df_u.loc[:, 'event'] = [evaluate_event(r) for r in df_u.iterrows()]
    df_u.loc[:, 'interaction'] = 'stop'
    df_u = df_u.drop(['arrival', 'departure', 'label', 'lat', 'lon', 'timestamp', 'user'], 1)
    return df_u


def processed_users(tc):
    interaction_types = ["call", "text", "physical", "screen", "stop"]
    counter = Counter()
    for t in interaction_types:
        users = [int(f.split(".")[0]) for f in os.listdir("build_dataset/data_cache/records/%s/%s" % (t, tc))]
        counter.update(users)
    return [k for k,v in counter.items() if v == 5]
    

tc = "tc1_spring"
skip_users = processed_users(tc)
for u in users:
    
    if u in skip_users:
        continue
    
    print "\nuser:", u
    try:
        df_call_u = _filter_call(df_call[df_call.loc[:, 'user'] == u])
        df_text_u = _filter_text(df_text[df_text.loc[:, 'user'] == u])
        df_physical_u = _filter_physical(u, df_physical.loc[(df_physical.loc[:, 'user'] == u) | \
                                                            (df_physical.loc[:, 'bt_mac'] == u), :])
        df_screen_u = _filter_screen(df_screen[df_screen.loc[:, 'user'] == u])
        df_stop_u = _filter_stops(u, df_stops[df_stops.loc[:, 'user'] == u])
    
        df_call_u.to_csv("build_dataset/data_cache/records/call/%s/%d.csv" % (tc, u), index=False)
        df_text_u.to_csv("build_dataset/data_cache/records/text/%s/%d.csv" % (tc, u), index=False)
        df_physical_u.to_csv("build_dataset/data_cache/records/physical/%s/%d.csv" % (tc, u), index=False)
        df_screen_u.to_csv("build_dataset/data_cache/records/screen/%s/%d.csv" % (tc, u), index=False)
        df_stop_u.to_csv("build_dataset/data_cache/records/stop/%s/%d.csv" % (tc, u), index=False)
    except:
        print "Failed:", u
# Out:
# user: 0
# _filter_call time: 0:00:00.027298
# _filter_text
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# time: 0:00:00.026823
# _filter_physical time: 0:00:00.668389
# _filter_screen time: 0:00:02.185128
# _filter_stops time: 0:00:01.180554
#
# user: 1
# _filter_call time: 0:00:00.002656
# _filter_text time: 0:00:00.004740
# _filter_physical time: 0:00:00.570920
# _filter_screen time: 0:00:00.294297
# _filter_stops time: 0:00:01.113185
#
# user: 2
# _filter_call time: 0:00:00.002730
# _filter_text time: 0:00:00.015357
# _filter_physical time: 0:00:00.541450
# _filter_screen time: 0:00:00.395491
# _filter_stops time: 0:00:01.101134
#
# user: 3
# _filter_call time: 0:00:00.005636
# _filter_text time: 0:00:00.027341
# _filter_physical time: 0:00:00.584631
# _filter_screen time: 0:00:01.431171
# _filter_stops time: 0:00:01.146566
#
# user: 4
# _filter_call time: 0:00:00.007566
# _filter_text time: 0:00:00.017125
# _filter_physical time: 0:00:00.584015
# _filter_screen time: 0:00:00.931094
# _filter_stops time: 0:00:01.138041
#
# user: 5
# _filter_call time: 0:00:00.005730
# _filter_text time: 0:00:00.075940
# _filter_physical time: 0:00:00.599614
# _filter_screen time: 0:00:01.988267
# _filter_stops time: 0:00:01.178560
#
# user: 6
# _filter_call time: 0:00:00.007917
# _filter_text time: 0:00:00.034031
# _filter_physical time: 0:00:00.642507
# _filter_screen time: 0:00:00.796444
# _filter_stops time: 0:00:01.135677
#
# user: 7
# _filter_call time: 0:00:00.004471
# _filter_text time: 0:00:00.007064
# _filter_physical time: 0:00:00.581616
# _filter_screen time: 0:00:00.607747
# _filter_stops time: 0:00:01.111108
#
# user: 8
# _filter_call time: 0:00:00.003036
# _filter_text time: 0:00:00.005397
# _filter_physical time: 0:00:00.640012
# _filter_screen time: 0:00:00.615628
# _filter_stops time: 0:00:01.118247
#
# user: 9
# _filter_call time: 0:00:00.003694
# _filter_text time: 0:00:00.002969
# _filter_physical time: 0:00:00.538459
# _filter_screen time: 0:00:00.170257
# _filter_stops time: 0:00:01.081683
#
# user: 10
# _filter_call time: 0:00:00.006823
# _filter_text time: 0:00:00.018780
# _filter_physical time: 0:00:00.561695
# _filter_screen time: 0:00:01.029713
# _filter_stops time: 0:00:01.164772
#
# user: 11
# _filter_call time: 0:00:00.006139
# _filter_text time: 0:00:00.021603
# _filter_physical time: 0:00:00.544721
# _filter_screen time: 0:00:01.045505
# _filter_stops time: 0:00:01.127799
#
# user: 12
# _filter_call time: 0:00:00.005833
# _filter_text time: 0:00:00.023195
# _filter_physical time: 0:00:00.673213
# _filter_screen time: 0:00:02.628188
# _filter_stops time: 0:00:01.166857
#
# user: 13
# _filter_call time: 0:00:00.004618
# _filter_text time: 0:00:00.016354
# _filter_physical time: 0:00:00.620040
# _filter_screen time: 0:00:01.098012
# _filter_stops time: 0:00:01.130186
#
# user: 14
# _filter_call time: 0:00:00.003122
# _filter_text time: 0:00:00.013615
# _filter_physical time: 0:00:00.556250
# _filter_screen time: 0:00:00.532878
# _filter_stops time: 0:00:01.126483
#
# user: 15
# _filter_call time: 0:00:00.007134
# _filter_text time: 0:00:00.010272
# _filter_physical time: 0:00:00.669881
# _filter_screen time: 0:00:00.813080
# _filter_stops time: 0:00:01.174005
#
# user: 16
# _filter_call time: 0:00:00.002564
# _filter_text time: 0:00:00.003604
# _filter_physical time: 0:00:00.568085
# _filter_screen time: 0:00:00.196776
# _filter_stops time: 0:00:01.089510
#
# user: 17
# _filter_call time: 0:00:00.005302
# _filter_text time: 0:00:00.007104
# _filter_physical time: 0:00:00.555030
# _filter_screen time: 0:00:01.269672
# _filter_stops time: 0:00:01.151431
#
# user: 18
# _filter_call time: 0:00:00.035321
# _filter_text time: 0:00:00.025118
# _filter_physical time: 0:00:00.584002
# _filter_screen time: 0:00:01.013207
# _filter_stops time: 0:00:01.186560
#
# user: 19
# _filter_call time: 0:00:00.011106
# _filter_text time: 0:00:00.016512
# _filter_physical time: 0:00:00.550852
# _filter_screen time: 0:00:01.798178
# _filter_stops time: 0:00:01.156526
#
# user: 20
# _filter_call time: 0:00:00.003617
# _filter_text time: 0:00:00.014572
# _filter_physical time: 0:00:00.573637
# _filter_screen time: 0:00:00.405816
# _filter_stops time: 0:00:01.095740
#
# user: 21
# _filter_call time: 0:00:00.005674
# _filter_text time: 0:00:00.029671
# _filter_physical time: 0:00:00.567739
# _filter_screen time: 0:00:01.511364
# _filter_stops time: 0:00:01.116978
#
# user: 22
# _filter_call time: 0:00:00.007738
# _filter_text time: 0:00:00.012966
# _filter_physical time: 0:00:00.573161
# _filter_screen time: 0:00:00.572621
# _filter_stops time: 0:00:01.086564
#
# user: 23
# _filter_call time: 0:00:00.006735
# _filter_text time: 0:00:00.081819
# _filter_physical time: 0:00:00.569238
# _filter_screen time: 0:00:01.417994
# _filter_stops time: 0:00:01.117875
#
# user: 24
# _filter_call time: 0:00:00.012185
# _filter_text time: 0:00:00.109817
# _filter_physical time: 0:00:00.542080
# _filter_screen time: 0:00:01.154146
# _filter_stops time: 0:00:01.117142
#
# user: 25
# _filter_call time: 0:00:00.005008
# _filter_text time: 0:00:00.002909
# _filter_physical time: 0:00:00.612658
# _filter_screen time: 0:00:00.953237
# _filter_stops time: 0:00:01.146871
#
# user: 26
# _filter_call time: 0:00:00.002843
# _filter_text time: 0:00:00.004496
# _filter_physical time: 0:00:00.566808
# _filter_screen time: 0:00:00.131384
# _filter_stops time: 0:00:01.128004
#
# user: 27
# _filter_call time: 0:00:00.005929
# _filter_text time: 0:00:00.013646
# _filter_physical time: 0:00:00.602278
# _filter_screen time: 0:00:00.699461
# _filter_stops time: 0:00:01.181227
#
# user: 28
# _filter_call time: 0:00:00.006199
# _filter_text time: 0:00:00.008212
# _filter_physical time: 0:00:00.553872
# _filter_screen time: 0:00:00.499825
# _filter_stops time: 0:00:01.112613
#
# user: 29
# _filter_call time: 0:00:00.008526
# _filter_text time: 0:00:00.017695
# _filter_physical time: 0:00:00.572873
# _filter_screen time: 0:00:00.412985
# _filter_stops time: 0:00:01.135050
#
# user: 30
# _filter_call time: 0:00:00.008360
# _filter_text time: 0:00:00.012731
# _filter_physical time: 0:00:00.584461
# _filter_screen time: 0:00:02.177705
# _filter_stops time: 0:00:01.172815
#
# user: 31
# _filter_call time: 0:00:00.005123
# _filter_text time: 0:00:00.032854
# _filter_physical time: 0:00:00.575802
# _filter_screen time: 0:00:00.833102
# _filter_stops time: 0:00:01.142609
#
# user: 32
# _filter_call time: 0:00:00.004513
# _filter_text time: 0:00:00.006242
# _filter_physical time: 0:00:00.573069
# _filter_screen time: 0:00:00.424341
# _filter_stops time: 0:00:01.154404
#
# user: 33
# _filter_call time: 0:00:00.007463
# _filter_text time: 0:00:00.079892
# _filter_physical time: 0:00:00.550499
# _filter_screen time: 0:00:02.129501
# _filter_stops time: 0:00:01.194472
#
# user: 34
# _filter_call time: 0:00:00.009167
# _filter_text time: 0:00:00.027539
# _filter_physical time: 0:00:00.602901
# _filter_screen time: 0:00:00.926974
# _filter_stops time: 0:00:01.163435
#
# user: 35
# _filter_call time: 0:00:00.006549
# _filter_text time: 0:00:00.020830
# _filter_physical time: 0:00:00.549702
# _filter_screen time: 0:00:00.589896
# _filter_stops time: 0:00:01.137788
#
# user: 36
# _filter_call time: 0:00:00.007143
# _filter_text time: 0:00:00.030673
# _filter_physical time: 0:00:00.679148
# _filter_screen time: 0:00:01.484537
# _filter_stops time: 0:00:01.170852
#
# user: 37
# _filter_call time: 0:00:00.016420
# _filter_text time: 0:00:00.034368
# _filter_physical time: 0:00:00.691970
# _filter_screen time: 0:00:01.187418
# _filter_stops time: 0:00:01.189276
#
# user: 38
# _filter_call time: 0:00:00.010818
# _filter_text time: 0:00:00.011172
# _filter_physical time: 0:00:00.598458
# _filter_screen time: 0:00:00.497822
# _filter_stops time: 0:00:01.167047
#
# user: 39
# _filter_call time: 0:00:00.012057
# _filter_text time: 0:00:00.020022
# _filter_physical time: 0:00:00.584370
# _filter_screen time: 0:00:00.926893
# _filter_stops time: 0:00:01.163567
#
# user: 40
# _filter_call time: 0:00:00.004348
# _filter_text time: 0:00:00.014339
# _filter_physical time: 0:00:00.547965
# _filter_screen time: 0:00:00.519474
# _filter_stops time: 0:00:01.123820
#
# user: 42
# _filter_call time: 0:00:00.003000
# _filter_text time: 0:00:00.013952
# _filter_physical time: 0:00:00.569609
# _filter_screen time: 0:00:00.529056
# _filter_stops time: 0:00:01.121780
#
# user: 43
# _filter_call time: 0:00:00.011763
# _filter_text time: 0:00:00.042286
# _filter_physical time: 0:00:00.562020
# _filter_screen time: 0:00:01.223399
# _filter_stops time: 0:00:01.159205
#
# user: 44
# _filter_call time: 0:00:00.004528
# _filter_text time: 0:00:00.005372
# _filter_physical time: 0:00:00.672936
# _filter_screen time: 0:00:00.489009
# _filter_stops time: 0:00:01.140803
#
# user: 45
# _filter_call time: 0:00:00.010783
# _filter_text time: 0:00:00.010037
# _filter_physical time: 0:00:00.554919
# _filter_screen time: 0:00:00.562767
# _filter_stops time: 0:00:01.185385
#
# user: 46
# _filter_call time: 0:00:00.006097
# _filter_text time: 0:00:00.020800
# _filter_physical time: 0:00:00.582454
# _filter_screen time: 0:00:01.224527
# _filter_stops time: 0:00:01.118963
#
# user: 47
# _filter_call time: 0:00:00.009359
# _filter_text time: 0:00:00.011262
# _filter_physical time: 0:00:00.646543
# _filter_screen time: 0:00:00.584128
# _filter_stops time: 0:00:01.111754
#
# user: 48
# _filter_call time: 0:00:00.007942
# _filter_text time: 0:00:00.031281
# _filter_physical time: 0:00:00.658328
# _filter_screen time: 0:00:00.901544
# _filter_stops time: 0:00:01.151620
#
# user: 49
# _filter_call time: 0:00:00.004872
# _filter_text time: 0:00:00.014794
# _filter_physical time: 0:00:00.665881
# _filter_screen time: 0:00:00.459274
# _filter_stops time: 0:00:01.109901
#
# user: 50
# _filter_call time: 0:00:00.006912
# _filter_text time: 0:00:00.014235
# _filter_physical time: 0:00:00.570733
# _filter_screen time: 0:00:00.911040
# _filter_stops time: 0:00:01.156263
#
# user: 51
# _filter_call time: 0:00:00.015199
# _filter_text time: 0:00:00.050924
# _filter_physical time: 0:00:00.594514
# _filter_screen time: 0:00:01.646265
# _filter_stops time: 0:00:01.177732
#
# user: 52
# _filter_call time: 0:00:00.004027
# _filter_text time: 0:00:00.013011
# _filter_physical time: 0:00:00.588874
# _filter_screen time: 0:00:00.579441
# _filter_stops time: 0:00:01.114845
#
# user: 53
# _filter_call time: 0:00:00.003999
# _filter_text time: 0:00:00.011373
# _filter_physical time: 0:00:00.569671
# _filter_screen time: 0:00:00.775075
# _filter_stops time: 0:00:01.114753
#
# user: 54
# _filter_call time: 0:00:00.005781
# _filter_text time: 0:00:00.023728
# _filter_physical time: 0:00:00.557341
# _filter_screen time: 0:00:02.130401
# _filter_stops time: 0:00:01.199889
#
# user: 55
# _filter_call time: 0:00:00.005344
# _filter_text time: 0:00:00.014059
# _filter_physical time: 0:00:00.552571
# _filter_screen time: 0:00:00.487511
# _filter_stops time: 0:00:01.138403
#
# user: 56
# _filter_call time: 0:00:00.002268
# _filter_text time: 0:00:00.003821
# _filter_physical time: 0:00:00.567150
# _filter_screen time: 0:00:00.068382
# _filter_stops time: 0:00:01.103516
#
# user: 57
# _filter_call time: 0:00:00.004056
# _filter_text time: 0:00:00.012909
# _filter_physical time: 0:00:00.665980
# _filter_screen time: 0:00:00.434822
# _filter_stops time: 0:00:01.144439
#
# user: 58
# _filter_call time: 0:00:00.004441
# _filter_text time: 0:00:00.014301
# _filter_physical time: 0:00:00.623830
# _filter_screen time: 0:00:01.052224
# _filter_stops time: 0:00:01.164607
#
# user: 59
# _filter_call time: 0:00:00.003815
# _filter_text time: 0:00:00.010581
# _filter_physical time: 0:00:00.561045
# _filter_screen time: 0:00:00.415953
# _filter_stops time: 0:00:01.101245
#
# user: 60
# _filter_call time: 0:00:00.003125
# _filter_text time: 0:00:00.008726
# _filter_physical time: 0:00:00.539303
# _filter_screen time: 0:00:00.214336
# _filter_stops time: 0:00:01.095297
#
# user: 61
# _filter_call time: 0:00:00.007390
# _filter_text time: 0:00:00.040352
# _filter_physical time: 0:00:00.623721
# _filter_screen time: 0:00:02.154881
# _filter_stops time: 0:00:01.156870
#
# user: 62
# _filter_call time: 0:00:00.005177
# _filter_text time: 0:00:00.005454
# _filter_physical time: 0:00:00.557819
# _filter_screen time: 0:00:00.540873
# _filter_stops time: 0:00:01.098705
#
# user: 63
# _filter_call time: 0:00:00.007347
# _filter_text time: 0:00:00.029737
# _filter_physical time: 0:00:00.575335
# _filter_screen time: 0:00:01.995286
# _filter_stops time: 0:00:01.211526
#
# user: 64
# _filter_call time: 0:00:00.004088
# _filter_text time: 0:00:00.008480
# _filter_physical time: 0:00:00.670365
# _filter_screen time: 0:00:01.096616
# _filter_stops time: 0:00:01.141480
#
# user: 65
# _filter_call time: 0:00:00.006670
# _filter_text time: 0:00:00.044487
# _filter_physical time: 0:00:00.576742
# _filter_screen time: 0:00:01.437700
# _filter_stops time: 0:00:01.176370
#
# user: 66
# _filter_call time: 0:00:00.006518
# _filter_text time: 0:00:00.052305
# _filter_physical time: 0:00:00.554998
# _filter_screen time: 0:00:00.858563
# _filter_stops time: 0:00:01.091708
#
# user: 67
# _filter_call time: 0:00:00.005041
# _filter_text time: 0:00:00.008021
# _filter_physical time: 0:00:00.550347
# _filter_screen time: 0:00:00.481143
# _filter_stops time: 0:00:01.117748
#
# user: 68
# _filter_call time: 0:00:00.006116
# _filter_text time: 0:00:00.015968
# _filter_physical time: 0:00:00.568880
# _filter_screen time: 0:00:01.240136
# _filter_stops time: 0:00:01.195373
#
# user: 69
# _filter_call time: 0:00:00.007158
# _filter_text time: 0:00:00.016015
# _filter_physical time: 0:00:00.599394
# _filter_screen time: 0:00:00.856858
# _filter_stops time: 0:00:01.147326
#
# user: 70
# _filter_call time: 0:00:00.003222
# _filter_text time: 0:00:00.005396
# _filter_physical time: 0:00:00.567063
# _filter_screen time: 0:00:00.404130
# _filter_stops time: 0:00:01.118099
#
# user: 71
# _filter_call time: 0:00:00.008153
# _filter_text time: 0:00:00.016016
# _filter_physical time: 0:00:00.549161
# _filter_screen time: 0:00:00.801953
# _filter_stops time: 0:00:01.134610
#
# user: 72
# _filter_call time: 0:00:00.007492
# _filter_text time: 0:00:00.031934
# _filter_physical time: 0:00:00.605529
# _filter_screen time: 0:00:01.968146
# _filter_stops time: 0:00:01.161431
#
# user: 73
# _filter_call time: 0:00:00.004019
# _filter_text time: 0:00:00.010757
# _filter_physical time: 0:00:00.602108
# _filter_screen time: 0:00:00.798843
# _filter_stops time: 0:00:01.133052
#
# user: 74
# _filter_call time: 0:00:00.003759
# _filter_text time: 0:00:00.014098
# _filter_physical time: 0:00:00.557392
# _filter_screen time: 0:00:00.504144
# _filter_stops time: 0:00:01.117676
#
# user: 75
# _filter_call time: 0:00:00.002775
# _filter_text time: 0:00:00.008767
# _filter_physical time: 0:00:00.551699
# _filter_screen time: 0:00:00.154565
# _filter_stops time: 0:00:01.100325
#
# user: 76
# _filter_call time: 0:00:00.004503
# _filter_text time: 0:00:00.010826
# _filter_physical time: 0:00:00.574378
# _filter_screen time: 0:00:00.570225
# _filter_stops time: 0:00:01.169784
#
# user: 77
# _filter_call time: 0:00:00.006956
# _filter_text time: 0:00:00.008810
# _filter_physical time: 0:00:00.539860
# _filter_screen time: 0:00:00.486839
# _filter_stops time: 0:00:01.121664
#
# user: 78
# _filter_call time: 0:00:00.004762
# _filter_text time: 0:00:00.046650
# _filter_physical time: 0:00:00.609948
# _filter_screen time: 0:00:01.416723
# _filter_stops time: 0:00:01.184117
#
# user: 79
# _filter_call time: 0:00:00.005925
# _filter_text time: 0:00:00.026164
# _filter_physical time: 0:00:00.583600
# _filter_screen time: 0:00:00.545887
# _filter_stops time: 0:00:01.136314
#
# user: 80
# _filter_call time: 0:00:00.005097
# _filter_text time: 0:00:00.005318
# _filter_physical time: 0:00:00.552701
# _filter_screen time: 0:00:00.372730
# _filter_stops time: 0:00:01.094973
#
# user: 81
# _filter_call time: 0:00:00.006208
# _filter_text time: 0:00:00.016396
# _filter_physical time: 0:00:00.598142
# _filter_screen time: 0:00:00.899008
# _filter_stops time: 0:00:01.177122
#
# user: 82
# _filter_call time: 0:00:00.006086
# _filter_text time: 0:00:00.020736
# _filter_physical time: 0:00:00.551623
# _filter_screen time: 0:00:01.121233
# _filter_stops time: 0:00:01.154197
#
# user: 83
# _filter_call time: 0:00:00.006823
# _filter_text time: 0:00:00.065159
# _filter_physical time: 0:00:00.581130
# _filter_screen time: 0:00:02.727000
# _filter_stops time: 0:00:01.188734
#
# user: 84
# _filter_call time: 0:00:00.008877
# _filter_text time: 0:00:00.014859
# _filter_physical time: 0:00:00.571252
# _filter_screen time: 0:00:01.066916
# _filter_stops time: 0:00:01.153118
#
# user: 85
# _filter_call time: 0:00:00.008110
# _filter_text time: 0:00:00.024186
# _filter_physical time: 0:00:00.666607
# _filter_screen time: 0:00:01.948791
# _filter_stops time: 0:00:01.176781
#
# user: 86
# _filter_call time: 0:00:00.007716
# _filter_text time: 0:00:00.021414
# _filter_physical time: 0:00:00.548679
# _filter_screen time: 0:00:01.175368
# _filter_stops time: 0:00:01.150170
#
# user: 87
# _filter_call time: 0:00:00.012244
# _filter_text time: 0:00:00.024860
# _filter_physical time: 0:00:00.562053
# _filter_screen time: 0:00:01.335338
# _filter_stops time: 0:00:01.170990
#
# user: 88
# _filter_call time: 0:00:00.011312
# _filter_text time: 0:00:00.039908
# _filter_physical time: 0:00:00.622461
# _filter_screen time: 0:00:01.763703
# _filter_stops time: 0:00:01.206055
#
# user: 89
# _filter_call time: 0:00:00.004043
# _filter_text time: 0:00:00.009036
# _filter_physical time: 0:00:00.552780
# _filter_screen time: 0:00:00.464685
# _filter_stops time: 0:00:01.101387
#
# user: 90
# _filter_call time: 0:00:00.006379
# _filter_text time: 0:00:00.023924
# _filter_physical time: 0:00:00.693406
# _filter_screen time: 0:00:00.582335
# _filter_stops time: 0:00:01.121405
#
# user: 91
# _filter_call time: 0:00:00.006953
# _filter_text time: 0:00:00.036755
# _filter_physical time: 0:00:00.695627
# _filter_screen time: 0:00:01.331510
# _filter_stops time: 0:00:01.141378
#
# user: 92
# _filter_call time: 0:00:00.005325
# _filter_text time: 0:00:00.048241
# _filter_physical time: 0:00:00.656268
# _filter_screen time: 0:00:01.259970
# _filter_stops time: 0:00:01.134855
#
# user: 93
# _filter_call time: 0:00:00.014823
# _filter_text time: 0:00:00.021980
# _filter_physical time: 0:00:00.575358
# _filter_screen time: 0:00:00.734825
# _filter_stops time: 0:00:01.125251
#
# user: 94
# _filter_call time: 0:00:00.010057
# _filter_text time: 0:00:00.049326
# _filter_physical time: 0:00:00.595856
# _filter_screen time: 0:00:01.360242
# _filter_stops time: 0:00:01.158449
#
# user: 95
# _filter_call time: 0:00:00.007267
# _filter_text time: 0:00:00.012399
# _filter_physical time: 0:00:00.680765
# _filter_screen time: 0:00:00.876503
# _filter_stops time: 0:00:01.171820
#
# user: 96
# _filter_call time: 0:00:00.007472
# _filter_text time: 0:00:00.027957
# _filter_physical time: 0:00:00.570542
# _filter_screen time: 0:00:01.207214
# _filter_stops time: 0:00:01.130454
#
# user: 97
# _filter_call time: 0:00:00.004214
# _filter_text time: 0:00:00.014814
# _filter_physical time: 0:00:00.574516
# _filter_screen time: 0:00:01.019427
# _filter_stops time: 0:00:01.120217
#
# user: 98
# _filter_call time: 0:00:00.007613
# _filter_text time: 0:00:00.014280
# _filter_physical time: 0:00:00.566623
# _filter_screen time: 0:00:00.679978
# _filter_stops time: 0:00:01.112061
#
# user: 99
# _filter_call time: 0:00:00.004539
# _filter_text time: 0:00:00.029699
# _filter_physical time: 0:00:00.554502
# _filter_screen time: 0:00:00.756122
# _filter_stops time: 0:00:01.125080
#
# user: 100
# _filter_call time: 0:00:00.009354
# _filter_text time: 0:00:00.076429
# _filter_physical time: 0:00:00.816877
# _filter_screen time: 0:00:03.143432
# _filter_stops time: 0:00:01.199703
#
# user: 101
# _filter_call time: 0:00:00.003177
# _filter_text time: 0:00:00.019090
# _filter_physical time: 0:00:00.557554
# _filter_screen time: 0:00:01.045727
# _filter_stops time: 0:00:01.152665
#
# user: 102
# _filter_call time: 0:00:00.005181
# _filter_text time: 0:00:00.021912
# _filter_physical time: 0:00:00.581709
# _filter_screen time: 0:00:00.934663
# _filter_stops time: 0:00:01.134295
#
# user: 103
# _filter_call time: 0:00:00.006298
# _filter_text time: 0:00:00.003249
# _filter_physical time: 0:00:00.538299
# _filter_screen time: 0:00:00.220628
# _filter_stops time: 0:00:01.073393
#
# user: 104
# _filter_call time: 0:00:00.005726
# _filter_text time: 0:00:00.061775
# _filter_physical time: 0:00:00.807885
# _filter_screen time: 0:00:01.947869
# _filter_stops time: 0:00:01.155353
#
# user: 105
# _filter_call time: 0:00:00.003710
# _filter_text time: 0:00:00.005574
# _filter_physical time: 0:00:00.570187
# _filter_screen time: 0:00:00.907419
# _filter_stops time: 0:00:01.134896
#
# user: 106
# _filter_call time: 0:00:00.011166
# _filter_text time: 0:00:00.012496
# _filter_physical time: 0:00:00.575808
# _filter_screen time: 0:00:01.503741
# _filter_stops time: 0:00:01.121857
#
# user: 107
# _filter_call time: 0:00:00.004329
# _filter_text time: 0:00:00.025496
# _filter_physical time: 0:00:00.559072
# _filter_screen time: 0:00:01.154752
# _filter_stops time: 0:00:01.165315
#
# user: 108
# _filter_call time: 0:00:00.004231
# _filter_text time: 0:00:00.030995
# _filter_physical time: 0:00:00.583084
# _filter_screen time: 0:00:02.586217
# _filter_stops time: 0:00:01.156233
#
# user: 109
# _filter_call time: 0:00:00.007580
# _filter_text time: 0:00:00.023314
# _filter_physical time: 0:00:00.574836
# _filter_screen time: 0:00:00.474156
# _filter_stops time: 0:00:01.120080
#
# user: 110
# _filter_call time: 0:00:00.014651
# _filter_text time: 0:00:00.004247
# _filter_physical time: 0:00:00.537949
# _filter_screen time: 0:00:00.545642
# _filter_stops time: 0:00:01.118250
#
# user: 111
# _filter_call time: 0:00:00.003191
# _filter_text time: 0:00:00.006263
# _filter_physical time: 0:00:00.557279
# _filter_screen time: 0:00:00.152679
# _filter_stops time: 0:00:01.087958
#
# user: 112
# _filter_call time: 0:00:00.002679
# _filter_text time: 0:00:00.004321
# _filter_physical time: 0:00:00.555605
# _filter_screen time: 0:00:00.113489
# _filter_stops time: 0:00:01.093079
#
# user: 113
# _filter_call time: 0:00:00.006522
# _filter_text time: 0:00:00.022769
# _filter_physical time: 0:00:00.569965
# _filter_screen time: 0:00:01.337217
# _filter_stops time: 0:00:01.122838
#
# user: 114
# _filter_call time: 0:00:00.005114
# _filter_text time: 0:00:00.036576
# _filter_physical time: 0:00:00.590563
# _filter_screen time: 0:00:00.617337
# _filter_stops time: 0:00:01.119303
#
# user: 115
# _filter_call time: 0:00:00.003114
# _filter_text time: 0:00:00.006826
# _filter_physical time: 0:00:00.543057
# _filter_screen time: 0:00:00.202434
# _filter_stops time: 0:00:01.084277
#
# user: 116
# _filter_call time: 0:00:00.006382
# _filter_text time: 0:00:00.011015
# _filter_physical time: 0:00:00.575927
# _filter_screen time: 0:00:01.141210
# _filter_stops time: 0:00:01.137577
#
# user: 117
# _filter_call time: 0:00:00.003022
# _filter_text time: 0:00:00.006882
# _filter_physical time: 0:00:00.539575
# _filter_screen time: 0:00:00.221454
# _filter_stops time: 0:00:01.100162
#
# user: 118
# _filter_call time: 0:00:00.004527
# _filter_text time: 0:00:00.012157
# _filter_physical time: 0:00:00.607750
# _filter_screen time: 0:00:01.009771
# _filter_stops time: 0:00:01.149714
#
# user: 119
# _filter_call time: 0:00:00.004097
# _filter_text time: 0:00:00.019764
# _filter_physical time: 0:00:00.592418
# _filter_screen time: 0:00:00.820465
# _filter_stops time: 0:00:01.123323
#
# user: 120
# _filter_call time: 0:00:00.006173
# _filter_text time: 0:00:00.015557
# _filter_physical time: 0:00:00.586869
# _filter_screen time: 0:00:00.680350
# _filter_stops time: 0:00:01.125304
#
# user: 121
# _filter_call time: 0:00:00.009198
# _filter_text time: 0:00:00.011915
# _filter_physical time: 0:00:00.628563
# _filter_screen time: 0:00:01.036547
# _filter_stops time: 0:00:01.151732
#
# user: 122
# _filter_call time: 0:00:00.004316
# _filter_text time: 0:00:00.008389
# _filter_physical time: 0:00:00.566169
# _filter_screen time: 0:00:00.216931
# _filter_stops time: 0:00:01.102659
#
# user: 123
# _filter_call time: 0:00:00.006101
# _filter_text time: 0:00:00.040816
# _filter_physical time: 0:00:00.582622
# _filter_screen time: 0:00:01.243976
# _filter_stops time: 0:00:01.143336
#
# user: 124
# _filter_call time: 0:00:00.012334
# _filter_text time: 0:00:00.029905
# _filter_physical time: 0:00:00.543651
# _filter_screen time: 0:00:00.694665
# _filter_stops time: 0:00:01.108612
#
# user: 125
# _filter_call time: 0:00:00.006147
# _filter_text time: 0:00:00.020258
# _filter_physical time: 0:00:00.551754
# _filter_screen time: 0:00:00.459216
# _filter_stops time: 0:00:01.132035
#
# user: 126
# _filter_call time: 0:00:00.007327
# _filter_text time: 0:00:00.016403
# _filter_physical time: 0:00:00.558430
# _filter_screen time: 0:00:00.668675
# _filter_stops time: 0:00:01.147876
#
# user: 127
# _filter_call time: 0:00:00.008458
# _filter_text time: 0:00:00.023975
# _filter_physical time: 0:00:00.553146
# _filter_screen time: 0:00:01.800783
# _filter_stops time: 0:00:01.119149
#
# user: 128
# _filter_call time: 0:00:00.005266
# _filter_text time: 0:00:00.019916
# _filter_physical time: 0:00:00.583503
# _filter_screen time: 0:00:00.819768
# _filter_stops time: 0:00:01.184718
#
# user: 129
# _filter_call time: 0:00:00.005547
# _filter_text time: 0:00:00.012584
# _filter_physical time: 0:00:00.557647
# _filter_screen time: 0:00:01.521390
# _filter_stops time: 0:00:01.122157
#
# user: 130
# _filter_call time: 0:00:00.008633
# _filter_text time: 0:00:00.008153
# _filter_physical time: 0:00:00.591243
# _filter_screen time: 0:00:00.857195
# _filter_stops time: 0:00:01.164046
#
# user: 131
# _filter_call time: 0:00:00.003869
# _filter_text time: 0:00:00.010849
# _filter_physical time: 0:00:00.540007
# _filter_screen time: 0:00:00.235592
# _filter_stops time: 0:00:01.090839
#
# user: 132
# _filter_call time: 0:00:00.004074
# _filter_text time: 0:00:00.019336
# _filter_physical time: 0:00:00.559205
# _filter_screen time: 0:00:00.594831
# _filter_stops time: 0:00:01.120790
#
# user: 133
# _filter_call time: 0:00:00.009270
# _filter_text time: 0:00:00.013580
# _filter_physical time: 0:00:00.658099
# _filter_screen time: 0:00:01.579115
# _filter_stops time: 0:00:01.164612
#
# user: 134
# _filter_call time: 0:00:00.002535
# _filter_text time: 0:00:00.003044
# _filter_physical time: 0:00:00.536387
# _filter_screen time: 0:00:00.027681
# _filter_stops time: 0:00:01.073091
#
# user: 135
# _filter_call time: 0:00:00.003264
# _filter_text time: 0:00:00.009217
# _filter_physical time: 0:00:00.541147
# _filter_screen time: 0:00:00.631070
# _filter_stops time: 0:00:01.091925
#
# user: 136
# _filter_call time: 0:00:00.008476
# _filter_text time: 0:00:00.037738
# _filter_physical time: 0:00:00.778784
# _filter_screen time: 0:00:01.539072
# _filter_stops time: 0:00:01.151705
#
# user: 137
# _filter_call time: 0:00:00.007275
# _filter_text time: 0:00:00.027777
# _filter_physical time: 0:00:00.757483
# _filter_screen time: 0:00:01.969657
# _filter_stops time: 0:00:01.100052
#
# user: 138
# _filter_call time: 0:00:00.012750
# _filter_text time: 0:00:00.021524
# _filter_physical time: 0:00:00.568102
# _filter_screen time: 0:00:01.178469
# _filter_stops time: 0:00:01.151737
#
# user: 139
# _filter_call time: 0:00:00.004491
# _filter_text time: 0:00:00.010356
# _filter_physical time: 0:00:00.620888
# _filter_screen time: 0:00:00.568651
# _filter_stops time: 0:00:01.143021
#
# user: 140
# _filter_call time: 0:00:00.011244
# _filter_text time: 0:00:00.032327
# _filter_physical time: 0:00:00.623552
# _filter_screen time: 0:00:01.283188
# _filter_stops time: 0:00:01.133088
#
# user: 141
# _filter_call time: 0:00:00.004631
# _filter_text time: 0:00:00.022998
# _filter_physical time: 0:00:00.562302
# _filter_screen time: 0:00:01.168407
# _filter_stops time: 0:00:01.147827
#
# user: 142
# _filter_call time: 0:00:00.003238
# _filter_text time: 0:00:00.008335
# _filter_physical time: 0:00:00.536881
# _filter_screen time: 0:00:00.084724
# _filter_stops time: 0:00:01.078795
#
# user: 143
# _filter_call time: 0:00:00.011737
# _filter_text time: 0:00:00.007316
# _filter_physical time: 0:00:00.554343
# _filter_screen time: 0:00:00.669555
# _filter_stops time: 0:00:01.138123
#
# user: 144
# _filter_call time: 0:00:00.004086
# _filter_text time: 0:00:00.010379
# _filter_physical time: 0:00:00.576958
# _filter_screen time: 0:00:00.307736
# _filter_stops time: 0:00:01.104180
#
# user: 145
# _filter_call time: 0:00:00.005188
# _filter_text time: 0:00:00.011612
# _filter_physical time: 0:00:00.542127
# _filter_screen time: 0:00:00.227789
# _filter_stops time: 0:00:01.103523
#
# user: 146
# _filter_call time: 0:00:00.009147
# _filter_text time: 0:00:00.031115
# _filter_physical time: 0:00:00.592751
# _filter_screen time: 0:00:00.803764
# _filter_stops time: 0:00:01.181777
#
# user: 147
# _filter_call time: 0:00:00.007699
# _filter_text time: 0:00:00.011748
# _filter_physical time: 0:00:00.559273
# _filter_screen time: 0:00:00.981528
# _filter_stops time: 0:00:01.148995
#
# user: 148
# _filter_call time: 0:00:00.003470
# _filter_text time: 0:00:00.013758
# _filter_physical time: 0:00:00.660169
# _filter_screen time: 0:00:00.562505
# _filter_stops time: 0:00:01.125565
#
# user: 149
# _filter_call time: 0:00:00.003245
# _filter_text time: 0:00:00.008068
# _filter_physical time: 0:00:00.663911
# _filter_screen time: 0:00:00.528333
# _filter_stops time: 0:00:01.113687
#
# user: 150
# _filter_call time: 0:00:00.004166
# _filter_text time: 0:00:00.005285
# _filter_physical time: 0:00:00.547492
# _filter_screen time: 0:00:00.551020
# _filter_stops time: 0:00:01.137089
#
# user: 151
# _filter_call time: 0:00:00.003369
# _filter_text time: 0:00:00.012526
# _filter_physical time: 0:00:00.566106
# _filter_screen time: 0:00:00.813025
# _filter_stops time: 0:00:01.109276
#
# user: 152
# _filter_call time: 0:00:00.006046
# _filter_text time: 0:00:00.010552
# _filter_physical time: 0:00:00.621096
# _filter_screen time: 0:00:00.739597
# _filter_stops time: 0:00:01.124827
#
# user: 153
# _filter_call time: 0:00:00.014738
# _filter_text time: 0:00:00.032708
# _filter_physical time: 0:00:00.555048
# _filter_screen time: 0:00:01.422463
# _filter_stops time: 0:00:01.174958
#
# user: 154
# _filter_call time: 0:00:00.002541
# _filter_text time: 0:00:00.008407
# _filter_physical time: 0:00:00.577552
# _filter_screen time: 0:00:00.774577
# _filter_stops time: 0:00:01.105449
#
# user: 155
# _filter_call time: 0:00:00.008561
# _filter_text time: 0:00:00.010749
# _filter_physical time: 0:00:00.585236
# _filter_screen time: 0:00:00.982922
# _filter_stops time: 0:00:01.150666
#
# user: 156
# _filter_call time: 0:00:00.003560
# _filter_text time: 0:00:00.006196
# _filter_physical time: 0:00:00.577683
# _filter_screen time: 0:00:00.994614
# _filter_stops time: 0:00:01.161103
#
# user: 157
# _filter_call time: 0:00:00.011386
# _filter_text time: 0:00:00.021616
# _filter_physical time: 0:00:00.586668
# _filter_screen time: 0:00:00.985835
# _filter_stops time: 0:00:01.154655
#
# user: 158
# _filter_call time: 0:00:00.012845
# _filter_text time: 0:00:00.035440
# _filter_physical time: 0:00:00.608122
# _filter_screen time: 0:00:01.386619
# _filter_stops time: 0:00:01.144674
#
# user: 159
# _filter_call time: 0:00:00.002617
# _filter_text time: 0:00:00.017038
# _filter_physical time: 0:00:00.570993
# _filter_screen time: 0:00:00.825785
# _filter_stops time: 0:00:01.104694
#
# user: 160
# _filter_call time: 0:00:00.009215
# _filter_text time: 0:00:00.022851
# _filter_physical time: 0:00:00.544922
# _filter_screen time: 0:00:01.668158
# _filter_stops time: 0:00:01.159561
#
# user: 161
# _filter_call time: 0:00:00.004959
# _filter_text time: 0:00:00.009677
# _filter_physical time: 0:00:00.565010
# _filter_screen time: 0:00:00.411466
# _filter_stops time: 0:00:01.102444
#
# user: 162
# _filter_call time: 0:00:00.003905
# _filter_text time: 0:00:00.005935
# _filter_physical time: 0:00:00.550263
# _filter_screen time: 0:00:00.308832
# _filter_stops time: 0:00:01.086845
#
# user: 163
# _filter_call time: 0:00:00.004164
# _filter_text time: 0:00:00.021197
# _filter_physical time: 0:00:00.645521
# _filter_screen time: 0:00:01.164698
# _filter_stops time: 0:00:01.113854
#
# user: 164
# _filter_call time: 0:00:00.005139
# _filter_text time: 0:00:00.043867
# _filter_physical time: 0:00:00.620405
# _filter_screen time: 0:00:01.060675
# _filter_stops time: 0:00:01.115365
#
# user: 165
# _filter_call time: 0:00:00.007848
# _filter_text time: 0:00:00.042696
# _filter_physical time: 0:00:00.585371
# _filter_screen time: 0:00:00.640918
# _filter_stops time: 0:00:01.144991
#
# user: 166
# _filter_call time: 0:00:00.010724
# _filter_text time: 0:00:00.040105
# _filter_physical time: 0:00:00.662254
# _filter_screen time: 0:00:02.046483
# _filter_stops time: 0:00:01.200767
#
# user: 167
# _filter_call time: 0:00:00.005913
# _filter_text time: 0:00:00.007548
# _filter_physical time: 0:00:00.563228
# _filter_screen time: 0:00:00.685371
# _filter_stops time: 0:00:01.093925
#
# user: 168
# _filter_call time: 0:00:00.004567
# _filter_text time: 0:00:00.005113
# _filter_physical time: 0:00:00.543781
# _filter_screen time: 0:00:01.047522
# _filter_stops time: 0:00:01.105594
#
# user: 169
# _filter_call time: 0:00:00.002846
# _filter_text time: 0:00:00.005423
# _filter_physical time: 0:00:00.624147
# _filter_screen time: 0:00:00.302712
# _filter_stops time: 0:00:01.124679
#
# user: 170
# _filter_call time: 0:00:00.004877
# _filter_text time: 0:00:00.018823
# _filter_physical time: 0:00:00.587191
# _filter_screen time: 0:00:00.545276
# _filter_stops time: 0:00:01.149452
#
# user: 171
# _filter_call time: 0:00:00.008569
# _filter_text time: 0:00:00.019890
# _filter_physical time: 0:00:00.563342
# _filter_screen time: 0:00:01.385331
# _filter_stops time: 0:00:01.148162
#
# user: 172
# _filter_call time: 0:00:00.007803
# _filter_text time: 0:00:00.027110
# _filter_physical time: 0:00:00.659559
# _filter_screen time: 0:00:00.899109
# _filter_stops time: 0:00:01.162276
#
# user: 173
# _filter_call time: 0:00:00.009260
# _filter_text time: 0:00:00.031028
# _filter_physical time: 0:00:00.649944
# _filter_screen time: 0:00:01.807871
# _filter_stops time: 0:00:01.196674
#
# user: 174
# _filter_call time: 0:00:00.005342
# _filter_text time: 0:00:00.017671
# _filter_physical time: 0:00:00.636187
# _filter_screen time: 0:00:01.276122
# _filter_stops time: 0:00:01.176901
#
# user: 175
# _filter_call time: 0:00:00.003084
# _filter_text time: 0:00:00.012591
# _filter_physical time: 0:00:00.590950
# _filter_screen time: 0:00:00.574136
# _filter_stops time: 0:00:01.104644
#
# user: 177
# _filter_call time: 0:00:00.003528
# _filter_text time: 0:00:00.012376
# _filter_physical time: 0:00:00.596999
# _filter_screen time: 0:00:00.756032
# _filter_stops time: 0:00:01.115511
#
# user: 178
# _filter_call time: 0:00:00.004858
# _filter_text time: 0:00:00.013409
# _filter_physical time: 0:00:00.604237
# _filter_screen time: 0:00:01.047846
# _filter_stops time: 0:00:01.164367
#
# user: 179
# _filter_call time: 0:00:00.004764
# _filter_text time: 0:00:00.030670
# _filter_physical time: 0:00:00.588214
# _filter_screen time: 0:00:00.815055
# _filter_stops time: 0:00:01.176554
#
# user: 180
# _filter_call time: 0:00:00.005838
# _filter_text time: 0:00:00.082772
# _filter_physical time: 0:00:00.689837
# _filter_screen time: 0:00:02.224870
# _filter_stops time: 0:00:01.167102
#
# user: 181
# _filter_call time: 0:00:00.003294
# _filter_text time: 0:00:00.004622
# _filter_physical time: 0:00:00.566512
# _filter_screen time: 0:00:00.241865
# _filter_stops time: 0:00:01.122219
#
# user: 182
# _filter_call time: 0:00:00.003725
# _filter_text time: 0:00:00.012713
# _filter_physical time: 0:00:00.750215
# _filter_screen time: 0:00:01.119889
# _filter_stops time: 0:00:01.124276
#
# user: 183
# _filter_call time: 0:00:00.007499
# _filter_text time: 0:00:00.085168
# _filter_physical time: 0:00:00.670653
# _filter_screen time: 0:00:03.103226
# _filter_stops time: 0:00:01.206393
#
# user: 184
# _filter_call time: 0:00:00.004046
# _filter_text time: 0:00:00.006876
# _filter_physical time: 0:00:00.543359
# _filter_screen time: 0:00:00.189002
# _filter_stops time: 0:00:01.095840
#
# user: 185
# _filter_call time: 0:00:00.017484
# _filter_text time: 0:00:00.012594
# _filter_physical time: 0:00:00.638158
# _filter_screen time: 0:00:02.287093
# _filter_stops time: 0:00:01.198289
#
# user: 186
# _filter_call time: 0:00:00.007653
# _filter_text time: 0:00:00.024996
# _filter_physical time: 0:00:00.567912
# _filter_screen time: 0:00:01.197595
# _filter_stops time: 0:00:01.165615
#
# user: 187
# _filter_call time: 0:00:00.007857
# _filter_text time: 0:00:00.037665
# _filter_physical time: 0:00:00.552676
# _filter_screen time: 0:00:01.774722
# _filter_stops time: 0:00:01.162668
#
# user: 188
# _filter_call time: 0:00:00.006619
# _filter_text time: 0:00:00.011208
# _filter_physical time: 0:00:00.606225
# _filter_screen time: 0:00:00.619642
# _filter_stops time: 0:00:01.137138
#
# user: 189
# _filter_call time: 0:00:00.002531
# _filter_text time: 0:00:00.009706
# _filter_physical time: 0:00:00.568851
# _filter_screen time: 0:00:00.489903
# _filter_stops time: 0:00:01.106371
#
# user: 190
# _filter_call time: 0:00:00.006543
# _filter_text time: 0:00:00.022228
# _filter_physical time: 0:00:00.600356
# _filter_screen time: 0:00:01.065448
# _filter_stops time: 0:00:01.133051
#
# user: 191
# _filter_call time: 0:00:00.005872
# _filter_text time: 0:00:00.006684
# _filter_physical time: 0:00:00.561488
# _filter_screen time: 0:00:01.199745
# _filter_stops time: 0:00:01.151590
#
# user: 192
# _filter_call time: 0:00:00.004482
# _filter_text time: 0:00:00.008693
# _filter_physical time: 0:00:00.573101
# _filter_screen time: 0:00:00.445832
# _filter_stops time: 0:00:01.124330
#
# user: 193
# _filter_call time: 0:00:00.003356
# _filter_text time: 0:00:00.020042
# _filter_physical time: 0:00:00.615725
# _filter_screen time: 0:00:00.980621
# _filter_stops time: 0:00:01.145790
#
# user: 194
# _filter_call time: 0:00:00.004337
# _filter_text time: 0:00:00.018944
# _filter_physical time: 0:00:00.604989
# _filter_screen time: 0:00:00.740906
# _filter_stops time: 0:00:01.158793
#
# user: 195
# _filter_call time: 0:00:00.006968
# _filter_text time: 0:00:00.058600
# _filter_physical time: 0:00:00.673366
# _filter_screen time: 0:00:01.861881
# _filter_stops time: 0:00:01.194391
#
# user: 196
# _filter_call time: 0:00:00.003933
# _filter_text time: 0:00:00.052067
# _filter_physical time: 0:00:00.575460
# _filter_screen time: 0:00:01.672774
# _filter_stops time: 0:00:01.134497
#
# user: 197
# _filter_call time: 0:00:00.003398
# _filter_text time: 0:00:00.040022
# _filter_physical time: 0:00:00.627627
# _filter_screen time: 0:00:01.842046
# _filter_stops time: 0:00:01.162237
#
# user: 198
# _filter_call time: 0:00:00.003008
# _filter_text time: 0:00:00.004228
# _filter_physical time: 0:00:00.644915
# _filter_screen time: 0:00:00.355941
# _filter_stops time: 0:00:01.145083
#
# user: 199
# _filter_call time: 0:00:00.006790
# _filter_text time: 0:00:00.066587
# _filter_physical time: 0:00:00.551408
# _filter_screen time: 0:00:00.946153
# _filter_stops time: 0:00:01.176341
#
# user: 200
# _filter_call time: 0:00:00.003893
# _filter_text time: 0:00:00.014732
# _filter_physical time: 0:00:00.592564
# _filter_screen time: 0:00:02.087879
# _filter_stops time: 0:00:01.136421
#
# user: 201
# _filter_call time: 0:00:00.003865
# _filter_text time: 0:00:00.044659
# _filter_physical time: 0:00:00.565247
# _filter_screen time: 0:00:00.651779
# _filter_stops time: 0:00:01.134590
#
# user: 202
# _filter_call time: 0:00:00.005726
# _filter_text time: 0:00:00.014161
# _filter_physical time: 0:00:00.544624
# _filter_screen time: 0:00:00.728435
# _filter_stops time: 0:00:01.138757
#
# user: 203
# _filter_call time: 0:00:00.011325
# _filter_text time: 0:00:00.048361
# _filter_physical time: 0:00:00.595798
# _filter_screen time: 0:00:01.869838
# _filter_stops time: 0:00:01.164324
#
# user: 204
# _filter_call time: 0:00:00.003918
# _filter_text time: 0:00:00.014326
# _filter_physical time: 0:00:00.603345
# _filter_screen time: 0:00:01.028872
# _filter_stops time: 0:00:01.165092
#
# user: 205
# _filter_call time: 0:00:00.007476
# _filter_text time: 0:00:00.028213
# _filter_physical time: 0:00:00.644252
# _filter_screen time: 0:00:01.411124
# _filter_stops time: 0:00:01.200158
#
# user: 206
# _filter_call time: 0:00:00.004300
# _filter_text time: 0:00:00.008272
# _filter_physical time: 0:00:00.568932
# _filter_screen time: 0:00:00.869254
# _filter_stops time: 0:00:01.152908
#
# user: 207
# _filter_call time: 0:00:00.006697
# _filter_text time: 0:00:00.017045
# _filter_physical time: 0:00:00.626599
# _filter_screen time: 0:00:00.874721
# _filter_stops time: 0:00:01.145125
#
# user: 208
# _filter_call time: 0:00:00.005572
# _filter_text time: 0:00:00.009633
# _filter_physical time: 0:00:00.646462
# _filter_screen time: 0:00:00.881275
# _filter_stops time: 0:00:01.173003
#
# user: 209
# _filter_call time: 0:00:00.004323
# _filter_text time: 0:00:00.013062
# _filter_physical time: 0:00:00.555742
# _filter_screen time: 0:00:00.964798
# _filter_stops time: 0:00:01.143047
#
# user: 210
# _filter_call time: 0:00:00.004965
# _filter_text time: 0:00:00.005557
# _filter_physical time: 0:00:00.611905
# _filter_screen time: 0:00:00.884198
# _filter_stops time: 0:00:01.180477
#
# user: 211
# _filter_call time: 0:00:00.011647
# _filter_text time: 0:00:00.060695
# _filter_physical time: 0:00:00.591481
# _filter_screen time: 0:00:01.520247
# _filter_stops time: 0:00:01.191016
#
# user: 213
# _filter_call time: 0:00:00.009883
# _filter_text time: 0:00:00.047975
# _filter_physical time: 0:00:00.577899
# _filter_screen time: 0:00:01.367670
# _filter_stops time: 0:00:01.187525
#
# user: 214
# _filter_call time: 0:00:00.006875
# _filter_text time: 0:00:00.021263
# _filter_physical time: 0:00:00.555934
# _filter_screen time: 0:00:01.495759
# _filter_stops time: 0:00:01.148105
#
# user: 215
# _filter_call time: 0:00:00.002602
# _filter_text time: 0:00:00.008685
# _filter_physical time: 0:00:00.588398
# _filter_screen time: 0:00:01.126643
# _filter_stops time: 0:00:01.158484
#
# user: 216
# _filter_call time: 0:00:00.007812
# _filter_text time: 0:00:00.009420
# _filter_physical time: 0:00:00.554555
# _filter_screen time: 0:00:00.451247
# _filter_stops time: 0:00:01.119185
#
# user: 217
# _filter_call time: 0:00:00.007334
# _filter_text time: 0:00:00.027638
# _filter_physical time: 0:00:00.634030
# _filter_screen time: 0:00:00.522868
# _filter_stops time: 0:00:01.131842
#
# user: 218
# _filter_call time: 0:00:00.007806
# _filter_text time: 0:00:00.055922
# _filter_physical time: 0:00:00.733238
# _filter_screen time: 0:00:02.376883
# _filter_stops time: 0:00:01.130946
#
# user: 219
# _filter_call time: 0:00:00.003625
# _filter_text time: 0:00:00.022686
# _filter_physical time: 0:00:00.557072
# _filter_screen time: 0:00:00.878279
# _filter_stops time: 0:00:01.141786
#
# user: 220
# _filter_call time: 0:00:00.009700
# _filter_text time: 0:00:00.026016
# _filter_physical time: 0:00:00.571057
# _filter_screen time: 0:00:00.633318
# _filter_stops time: 0:00:01.138355
#
# user: 221
# _filter_call time: 0:00:00.010660
# _filter_text time: 0:00:00.031559
# _filter_physical time: 0:00:00.650992
# _filter_screen time: 0:00:01.049965
# _filter_stops time: 0:00:01.173068
#
# user: 222
# _filter_call time: 0:00:00.004512
# _filter_text time: 0:00:00.008712
# _filter_physical time: 0:00:00.593932
# _filter_screen time: 0:00:01.637105
# _filter_stops time: 0:00:01.163943
#
# user: 223
# _filter_call time: 0:00:00.009367
# _filter_text time: 0:00:00.020315
# _filter_physical time: 0:00:00.581228
# _filter_screen time: 0:00:01.398423
# _filter_stops time: 0:00:01.148044
#
# user: 224
# _filter_call time: 0:00:00.006392
# _filter_text time: 0:00:00.025508
# _filter_physical time: 0:00:00.619488
# _filter_screen time: 0:00:00.954464
# _filter_stops time: 0:00:01.145642
#
# user: 225
# _filter_call time: 0:00:00.018174
# _filter_text time: 0:00:00.053854
# _filter_physical time: 0:00:00.658999
# _filter_screen time: 0:00:01.456805
# _filter_stops time: 0:00:01.188377
#
# user: 226
# _filter_call time: 0:00:00.006349
# _filter_text time: 0:00:00.022338
# _filter_physical time: 0:00:00.607562
# _filter_screen time: 0:00:01.304830
# _filter_stops time: 0:00:01.155265
#
# user: 227
# _filter_call time: 0:00:00.004190
# _filter_text time: 0:00:00.012085
# _filter_physical time: 0:00:00.568628
# _filter_screen time: 0:00:01.000866
# _filter_stops time: 0:00:01.157428
#
# user: 228
# _filter_call time: 0:00:00.004211
# _filter_text time: 0:00:00.009269
# _filter_physical time: 0:00:00.556908
# _filter_screen time: 0:00:01.504866
# _filter_stops time: 0:00:01.138556
#
# user: 229
# _filter_call time: 0:00:00.005318
# _filter_text time: 0:00:00.010950
# _filter_physical time: 0:00:00.606165
# _filter_screen time: 0:00:00.417998
# _filter_stops time: 0:00:01.133827
#
# user: 230
# _filter_call time: 0:00:00.005671
# _filter_text time: 0:00:00.014207
# _filter_physical time: 0:00:00.575850
# _filter_screen time: 0:00:01.235604
# _filter_stops time: 0:00:01.172232
#
# user: 231
# _filter_call time: 0:00:00.003471
# _filter_text time: 0:00:00.006423
# _filter_physical time: 0:00:00.568353
# _filter_screen time: 0:00:00.403637
# _filter_stops time: 0:00:01.112252
#
# user: 232
# _filter_call time: 0:00:00.005550
# _filter_text time: 0:00:00.013369
# _filter_physical time: 0:00:00.603270
# _filter_screen time: 0:00:00.266769
# _filter_stops time: 0:00:01.155600
#
# user: 233
# _filter_call time: 0:00:00.018666
# _filter_text time: 0:00:00.051535
# _filter_physical time: 0:00:00.558889
# _filter_screen time: 0:00:02.080707
# _filter_stops time: 0:00:01.214370
#
# user: 234
# _filter_call time: 0:00:00.005718
# _filter_text time: 0:00:00.009954
# _filter_physical time: 0:00:00.581231
# _filter_screen time: 0:00:01.322091
# _filter_stops time: 0:00:01.174820
#
# user: 235
# _filter_call time: 0:00:00.006029
# _filter_text time: 0:00:00.021392
# _filter_physical time: 0:00:00.585253
# _filter_screen time: 0:00:00.673923
# _filter_stops time: 0:00:01.143918
#
# user: 236
# _filter_call time: 0:00:00.005083
# _filter_text time: 0:00:00.014501
# _filter_physical time: 0:00:00.561113
# _filter_screen time: 0:00:00.151325
# _filter_stops time: 0:00:01.095902
#
# user: 237
# _filter_call time: 0:00:00.007611
# _filter_text time: 0:00:00.026500
# _filter_physical time: 0:00:00.689639
# _filter_screen time: 0:00:00.942613
# _filter_stops time: 0:00:01.172220
#
# user: 238
# _filter_call time: 0:00:00.004504
# _filter_text time: 0:00:00.011534
# _filter_physical time: 0:00:00.593371
# _filter_screen time: 0:00:01.259238
# _filter_stops time: 0:00:01.126444
#
# user: 239
# _filter_call time: 0:00:00.004076
# _filter_text time: 0:00:00.045579
# _filter_physical time: 0:00:00.566594
# _filter_screen time: 0:00:00.764103
# _filter_stops time: 0:00:01.124016
#
# user: 240
# _filter_call time: 0:00:00.003122
# _filter_text time: 0:00:00.004586
# _filter_physical time: 0:00:00.595686
# _filter_screen time: 0:00:00.819363
# _filter_stops time: 0:00:01.140562
#
# user: 241
# _filter_call time: 0:00:00.003397
# _filter_text time: 0:00:00.083677
# _filter_physical time: 0:00:00.547539
# _filter_screen time: 0:00:01.402545
# _filter_stops time: 0:00:01.143629
#
# user: 242
# _filter_call time: 0:00:00.008082
# _filter_text time: 0:00:00.060280
# _filter_physical time: 0:00:00.606770
# _filter_screen time: 0:00:01.309322
# _filter_stops time: 0:00:01.198307
#
# user: 243
# _filter_call time: 0:00:00.013683
# _filter_text time: 0:00:00.125358
# _filter_physical time: 0:00:00.641445
# _filter_screen time: 0:00:02.529802
# _filter_stops time: 0:00:01.165406
#
# user: 244
# _filter_call time: 0:00:00.011688
# _filter_text time: 0:00:00.048697
# _filter_physical time: 0:00:00.613498
# _filter_screen time: 0:00:01.233385
# _filter_stops time: 0:00:01.201130
#
# user: 245
# _filter_call time: 0:00:00.003263
# _filter_text time: 0:00:00.011527
# _filter_physical time: 0:00:00.544753
# _filter_screen time: 0:00:00.326924
# _filter_stops time: 0:00:01.098566
#
# user: 246
# _filter_call time: 0:00:00.007434
# _filter_text time: 0:00:00.031673
# _filter_physical time: 0:00:00.604572
# _filter_screen time: 0:00:01.070494
# _filter_stops time: 0:00:01.197425
#
# user: 247
# _filter_call time: 0:00:00.006498
# _filter_text time: 0:00:00.010795
# _filter_physical time: 0:00:00.553823
# _filter_screen time: 0:00:01.334847
# _filter_stops time: 0:00:01.167095
#
# user: 248
# _filter_call time: 0:00:00.003979
# _filter_text time: 0:00:00.007622
# _filter_physical time: 0:00:00.553033
# _filter_screen time: 0:00:00.498158
# _filter_stops time: 0:00:01.161044
#
# user: 249
# _filter_call time: 0:00:00.003672
# _filter_text time: 0:00:00.005774
# _filter_physical time: 0:00:00.655750
# _filter_screen time: 0:00:01.148481
# _filter_stops time: 0:00:01.093642
#
# user: 250
# _filter_call time: 0:00:00.006822
# _filter_text time: 0:00:00.016440
# _filter_physical time: 0:00:00.602578
# _filter_screen time: 0:00:01.487139
# _filter_stops time: 0:00:01.173195
#
# user: 251
# _filter_call time: 0:00:00.016856
# _filter_text time: 0:00:00.012360
# _filter_physical time: 0:00:00.567575
# _filter_screen time: 0:00:01.221947
# _filter_stops time: 0:00:01.174498
#
# user: 252
# _filter_call time: 0:00:00.038912
# _filter_text time: 0:00:00.018255
# _filter_physical time: 0:00:00.563178
# _filter_screen time: 0:00:01.430090
# _filter_stops time: 0:00:01.179130
#
# user: 253
# _filter_call time: 0:00:00.003787
# _filter_text time: 0:00:00.020103
# _filter_physical time: 0:00:00.563504
# _filter_screen time: 0:00:00.961265
# _filter_stops time: 0:00:01.123321
#
# user: 254
# _filter_call time: 0:00:00.005560
# _filter_text time: 0:00:00.018073
# _filter_physical time: 0:00:00.604603
# _filter_screen time: 0:00:00.699673
# ...
# _filter_stops time: 0:00:01.149489
#
# user: 700
# _filter_call time: 0:00:00.003859
# _filter_text time: 0:00:00.028330
# _filter_physical time: 0:00:00.552808
# _filter_screen time: 0:00:00.691913
# _filter_stops time: 0:00:01.101500
#
# user: 701
# _filter_call time: 0:00:00.010819
# _filter_text time: 0:00:00.023740
# _filter_physical time: 0:00:00.559804
# _filter_screen time: 0:00:01.220712
# _filter_stops time: 0:00:01.151712
#
# user: 702
# _filter_call time: 0:00:00.007894
# _filter_text time: 0:00:00.021547
# _filter_physical time: 0:00:00.624051
# _filter_screen time: 0:00:01.011469
# _filter_stops time: 0:00:01.150451
#
# user: 703
# _filter_call time: 0:00:00.007579
# _filter_text time: 0:00:00.011929
# _filter_physical time: 0:00:00.560955
# _filter_screen time: 0:00:00.571047
# _filter_stops time: 0:00:01.128341
#
# user: 705
# _filter_call time: 0:00:00.027725
# _filter_text time: 0:00:00.006513
# _filter_physical time: 0:00:00.540019
# _filter_screen time: 0:00:00.753090
# _filter_stops time: 0:00:01.130583
#
# user: 706
# _filter_call time: 0:00:00.002342
# _filter_text time: 0:00:00.003909
# _filter_physical time: 0:00:00.539592
# _filter_screen time: 0:00:00.063232
# _filter_stops time: 0:00:01.078630
#
# user: 707
# _filter_call time: 0:00:00.003787
# _filter_text time: 0:00:00.014089
# _filter_physical time: 0:00:00.585199
# _filter_screen time: 0:00:02.034469
# _filter_stops time: 0:00:01.087613
#
# user: 708
# _filter_call time: 0:00:00.006097
# _filter_text time: 0:00:00.007985
# _filter_physical time: 0:00:00.537271
# _filter_screen time: 0:00:00.220461
# _filter_stops time: 0:00:01.098766
#
# user: 710
# _filter_call time: 0:00:00.005442
# _filter_text time: 0:00:00.006022
# _filter_physical time: 0:00:00.535799
# _filter_screen time: 0:00:00.032273
# _filter_stops Failed: 710
#
# user: 711
# _filter_call time: 0:00:00.008100
# _filter_text time: 0:00:00.021453
# _filter_physical time: 0:00:00.543364
# _filter_screen time: 0:00:00.841140
# _filter_stops time: 0:00:01.124090
#
# user: 716
# _filter_call time: 0:00:00.003160
# _filter_text time: 0:00:00.003165
# _filter_physical time: 0:00:00.536038
# _filter_screen time: 0:00:00.045621
# _filter_stops time: 0:00:01.076250
#
# user: 717
# _filter_call time: 0:00:00.008329
# _filter_text time: 0:00:00.012015
# _filter_physical time: 0:00:00.579508
# _filter_screen time: 0:00:00.648606
# _filter_stops time: 0:00:01.111805
#
# user: 718
# _filter_call time: 0:00:00.003800
# _filter_text time: 0:00:00.012813
# _filter_physical time: 0:00:00.543792
# _filter_screen time: 0:00:00.599001
# _filter_stops time: 0:00:01.102127
#
# user: 719
# _filter_call time: 0:00:00.004042
# _filter_text time: 0:00:00.012929
# _filter_physical time: 0:00:00.572866
# _filter_screen time: 0:00:00.973188
# _filter_stops time: 0:00:01.102664
#
# user: 720
# _filter_call time: 0:00:00.004961
# _filter_text time: 0:00:00.013589
# _filter_physical time: 0:00:00.601373
# _filter_screen time: 0:00:01.122080
# _filter_stops time: 0:00:01.133040
#
# user: 721
# _filter_call time: 0:00:00.004562
# _filter_text time: 0:00:00.010308
# _filter_physical time: 0:00:00.578512
# _filter_screen time: 0:00:00.479476
# _filter_stops time: 0:00:01.124033
#
# user: 722
# _filter_call time: 0:00:00.003196
# _filter_text time: 0:00:00.008414
# _filter_physical time: 0:00:00.544296
# _filter_screen time: 0:00:00.493044
# _filter_stops time: 0:00:01.086378
#
# user: 723
# _filter_call time: 0:00:00.006750
# _filter_text time: 0:00:00.008865
# _filter_physical time: 0:00:00.555371
# _filter_screen time: 0:00:01.204440
# _filter_stops time: 0:00:01.147289
#
# user: 724
# _filter_call time: 0:00:00.002311
# _filter_text time: 0:00:00.003183
# _filter_physical time: 0:00:00.538449
# _filter_screen time: 0:00:00.039074
# _filter_stops time: 0:00:01.073315
#
# user: 725
# _filter_call time: 0:00:00.005138
# _filter_text time: 0:00:00.009800
# _filter_physical time: 0:00:00.548769
# _filter_screen time: 0:00:00.947222
# _filter_stops time: 0:00:01.164006
#
# user: 726
# _filter_call time: 0:00:00.002770
# _filter_text time: 0:00:00.006423
# _filter_physical time: 0:00:00.538439
# _filter_screen time: 0:00:00.141391
# _filter_stops time: 0:00:01.084360
#
# user: 728
# _filter_call time: 0:00:00.002571
# _filter_text time: 0:00:00.004081
# _filter_physical time: 0:00:00.548535
# _filter_screen time: 0:00:00.232207
# _filter_stops time: 0:00:01.081990
#
# user: 729
# _filter_call time: 0:00:00.005515
# _filter_text time: 0:00:00.027922
# _filter_physical time: 0:00:00.584979
# _filter_screen time: 0:00:00.749090
# _filter_stops time: 0:00:01.142811
#
# user: 730
# _filter_call time: 0:00:00.005193
# _filter_text time: 0:00:00.020740
# _filter_physical time: 0:00:00.537409
# _filter_screen time: 0:00:00.265975
# _filter_stops time: 0:00:01.103444
#
# user: 733
# _filter_call time: 0:00:00.005839
# _filter_text time: 0:00:00.017453
# _filter_physical time: 0:00:00.577059
# _filter_screen time: 0:00:01.042941
# _filter_stops time: 0:00:01.109336
#
# user: 735
# _filter_call time: 0:00:00.006179
# _filter_text time: 0:00:00.015200
# _filter_physical time: 0:00:00.541288
# _filter_screen time: 0:00:00.658984
# _filter_stops time: 0:00:01.138353
#
# user: 736
# _filter_call time: 0:00:00.002052
# _filter_text time: 0:00:00.003389
# _filter_physical time: 0:00:00.536775
# _filter_screen time: 0:00:00.053126
# _filter_stops time: 0:00:01.075227
#
# user: 741
# _filter_call time: 0:00:00.002259
# _filter_text time: 0:00:00.004788
# _filter_physical time: 0:00:00.536576
# _filter_screen time: 0:00:00.050700
# _filter_stops time: 0:00:01.072165
#
# user: 745
# _filter_call time: 0:00:00.002114
# _filter_text time: 0:00:00.004114
# _filter_physical time: 0:00:00.536690
# _filter_screen time: 0:00:00.057833
# _filter_stops time: 0:00:01.073197
#
# user: 751
# _filter_call time: 0:00:00.002312
# _filter_text time: 0:00:00.003115
# _filter_physical time: 0:00:00.536277
# _filter_screen time: 0:00:00.038007
# _filter_stops time: 0:00:01.077285
#
# user: 760
# _filter_call time: 0:00:00.007365
# _filter_text time: 0:00:00.022619
# _filter_physical time: 0:00:00.547012
# _filter_screen time: 0:00:00.798733
# _filter_stops time: 0:00:01.121813
#
# user: 761
# _filter_call time: 0:00:00.002008
# _filter_text time: 0:00:00.003218
# _filter_physical time: 0:00:00.540903
# _filter_screen time: 0:00:00.126464
# _filter_stops time: 0:00:01.074748
#
# user: 762
# _filter_call time: 0:00:00.002765
# _filter_text time: 0:00:00.002989
# _filter_physical time: 0:00:00.536263
# _filter_screen time: 0:00:00.007081
# _filter_stops time: 0:00:01.072749
#
# user: 763
# _filter_call time: 0:00:00.001942
# _filter_text time: 0:00:00.002928
# _filter_physical time: 0:00:00.536159
# _filter_screen time: 0:00:00.007532
# _filter_stops time: 0:00:01.071535
#
# user: 767
# _filter_call time: 0:00:00.005085
# _filter_text time: 0:00:00.004725
# _filter_physical time: 0:00:00.535008
# _filter_screen time: 0:00:00.006936
# _filter_stops time: 0:00:01.070746
#
# user: 773
# _filter_call time: 0:00:00.002210
# _filter_text time: 0:00:00.004441
# _filter_physical time: 0:00:00.536399
# _filter_screen time: 0:00:00.040772
# _filter_stops time: 0:00:01.074221
#
# user: 774
# _filter_call time: 0:00:00.002187
# _filter_text time: 0:00:00.008677
# _filter_physical time: 0:00:00.537395
# _filter_screen time: 0:00:00.109978
# _filter_stops time: 0:00:01.081728
#
# user: 780
# _filter_call time: 0:00:00.002375
# _filter_text time: 0:00:00.004195
# _filter_physical time: 0:00:00.548225
# _filter_screen time: 0:00:00.088893
# _filter_stops time: 0:00:01.074710
#
# user: 784
# _filter_call time: 0:00:00.002709
# _filter_text time: 0:00:00.003415
# _filter_physical time: 0:00:00.537234
# _filter_screen time: 0:00:00.069613
# _filter_stops time: 0:00:01.074849
#
# user: 786
# _filter_call time: 0:00:00.003864
# _filter_text time: 0:00:00.007632
# _filter_physical time: 0:00:00.561268
# _filter_screen time: 0:00:00.324970
# _filter_stops time: 0:00:01.116742
#
# user: 787
# _filter_call time: 0:00:00.003252
# _filter_text time: 0:00:00.007000
# _filter_physical time: 0:00:00.535029
# _filter_screen time: 0:00:00.079743
# _filter_stops time: 0:00:01.076765
#
# user: 790
# _filter_call time: 0:00:00.002807
# _filter_text time: 0:00:00.011924
# _filter_physical time: 0:00:00.538223
# _filter_screen time: 0:00:00.101271
# _filter_stops time: 0:00:01.078362
#
# user: 797
# _filter_call time: 0:00:00.002024
# _filter_text time: 0:00:00.003126
# _filter_physical time: 0:00:00.547979
# _filter_screen time: 0:00:00.055312
# _filter_stops time: 0:00:01.076350
#
# user: 798
# _filter_call time: 0:00:00.003795
# _filter_text time: 0:00:00.016992
# _filter_physical time: 0:00:00.536018
# _filter_screen time: 0:00:00.012953
# _filter_stops time: 0:00:01.070901
#
# user: 799
# _filter_call time: 0:00:00.002858
# _filter_text time: 0:00:00.003850
# _filter_physical time: 0:00:00.537041
# _filter_screen time: 0:00:00.036135
# _filter_stops time: 0:00:01.070808
#
# user: 800
# _filter_call time: 0:00:00.002330
# _filter_text time: 0:00:00.003190
# _filter_physical time: 0:00:00.536026
# _filter_screen time: 0:00:00.070549
# _filter_stops time: 0:00:01.094451
#
# user: 802
# _filter_call time: 0:00:00.001929
# _filter_text time: 0:00:00.003276
# _filter_physical time: 0:00:00.537144
# _filter_screen time: 0:00:00.006573
# _filter_stops time: 0:00:01.074390
#
# user: 809
# _filter_call time: 0:00:00.001873
# _filter_text time: 0:00:00.006719
# _filter_physical time: 0:00:00.536565
# _filter_screen time: 0:00:00.058638
# _filter_stops time: 0:00:01.074964
#
# user: 810
# _filter_call time: 0:00:00.004931
# _filter_text time: 0:00:00.012672
# _filter_physical time: 0:00:00.551110
# _filter_screen time: 0:00:00.351929
# _filter_stops time: 0:00:01.111146
#
# user: 811
# _filter_call time: 0:00:00.002307
# _filter_text time: 0:00:00.003056
# _filter_physical time: 0:00:00.536080
# _filter_screen time: 0:00:00.019362
# _filter_stops time: 0:00:01.074817
#
# user: 812
# _filter_call time: 0:00:00.004104
# _filter_text time: 0:00:00.006106
# _filter_physical time: 0:00:00.552992
# _filter_screen time: 0:00:00.161496
# _filter_stops time: 0:00:01.075466
#
# user: 813
# _filter_call time: 0:00:00.001939
# _filter_text time: 0:00:00.002924
# _filter_physical time: 0:00:00.537602
# _filter_screen time: 0:00:00.018594
# _filter_stops time: 0:00:01.076078
#
# user: 814
# _filter_call time: 0:00:00.005161
# _filter_text time: 0:00:00.018079
# _filter_physical time: 0:00:00.561208
# _filter_screen time: 0:00:00.695319
# _filter_stops time: 0:00:01.110646
#
# user: 815
# _filter_call time: 0:00:00.007163
# _filter_text time: 0:00:00.011103
# _filter_physical time: 0:00:00.547315
# _filter_screen time: 0:00:00.396437
# _filter_stops time: 0:00:01.124648
#
# user: 816
# _filter_call time: 0:00:00.004568
# _filter_text time: 0:00:00.007434
# _filter_physical time: 0:00:00.637403
# _filter_screen time: 0:00:00.620078
# _filter_stops time: 0:00:01.113898
#
# user: 817
# _filter_call time: 0:00:00.004243
# _filter_text time: 0:00:00.015723
# _filter_physical time: 0:00:00.576346
# _filter_screen time: 0:00:00.809702
# _filter_stops time: 0:00:01.115658
#
# user: 818
# _filter_call time: 0:00:00.004065
# _filter_text time: 0:00:00.011212
# _filter_physical time: 0:00:00.597705
# _filter_screen time: 0:00:00.441488
# _filter_stops time: 0:00:01.099580
#
# user: 819
# _filter_call time: 0:00:00.008862
# _filter_text time: 0:00:00.025957
# _filter_physical time: 0:00:00.555349
# _filter_screen time: 0:00:00.908617
# _filter_stops time: 0:00:01.146797
#
# user: 820
# _filter_call time: 0:00:00.003327
# _filter_text time: 0:00:00.008266
# _filter_physical time: 0:00:00.550693
# _filter_screen time: 0:00:00.257272
# _filter_stops time: 0:00:01.086398
#
# user: 822
# _filter_call time: 0:00:00.012812
# _filter_text time: 0:00:00.010546
# _filter_physical time: 0:00:00.543963
# _filter_screen time: 0:00:00.594996
# _filter_stops time: 0:00:01.108516
#
# user: 823
# _filter_call time: 0:00:00.006725
# _filter_text time: 0:00:00.014863
# _filter_physical time: 0:00:00.544764
# _filter_screen time: 0:00:00.386896
# _filter_stops time: 0:00:01.131492
#
# user: 824
# _filter_call time: 0:00:00.003020
# _filter_text time: 0:00:00.008136
# _filter_physical time: 0:00:00.559800
# _filter_screen time: 0:00:00.669797
# _filter_stops time: 0:00:01.074236
#
# user: 825
# _filter_call time: 0:00:00.003562
# _filter_text time: 0:00:00.010034
# _filter_physical time: 0:00:00.541317
# _filter_screen time: 0:00:01.014951
# _filter_stops time: 0:00:01.124641
#
# user: 826
# _filter_call time: 0:00:00.006427
# _filter_text time: 0:00:00.034700
# _filter_physical time: 0:00:00.577404
# _filter_screen time: 0:00:00.876567
# _filter_stops time: 0:00:01.122073
#
# user: 827
# _filter_call time: 0:00:00.008473
# _filter_text time: 0:00:00.022657
# _filter_physical time: 0:00:00.551446
# _filter_screen time: 0:00:01.001518
# _filter_stops time: 0:00:01.140346
#
# user: 828
# _filter_call time: 0:00:00.006018
# _filter_text time: 0:00:00.020464
# _filter_physical time: 0:00:00.550979
# _filter_screen time: 0:00:00.624576
# _filter_stops time: 0:00:01.130747
#
# user: 829
# _filter_call time: 0:00:00.003196
# _filter_text time: 0:00:00.009249
# _filter_physical time: 0:00:00.536356
# _filter_screen time: 0:00:00.034153
# _filter_stops time: 0:00:01.073072
#
# user: 830
# _filter_call time: 0:00:00.008206
# _filter_text time: 0:00:00.012678
# _filter_physical time: 0:00:00.546438
# _filter_screen time: 0:00:00.251807
# _filter_stops time: 0:00:01.084644
#
# user: 831
# _filter_call time: 0:00:00.005571
# _filter_text time: 0:00:00.010154
# _filter_physical time: 0:00:00.544384
# _filter_screen time: 0:00:00.894541
# _filter_stops time: 0:00:01.130414
#
# user: 832
# _filter_call time: 0:00:00.002601
# _filter_text time: 0:00:00.004401
# _filter_physical time: 0:00:00.548982
# _filter_screen time: 0:00:00.123785
# _filter_stops time: 0:00:01.082246
#
# user: 833
# _filter_call time: 0:00:00.004408
# _filter_text time: 0:00:00.007969
# _filter_physical time: 0:00:00.554972
# _filter_screen time: 0:00:00.817387
# _filter_stops time: 0:00:01.122954
#
# user: 834
# _filter_call time: 0:00:00.003061
# _filter_text time: 0:00:00.031710
# _filter_physical time: 0:00:00.546434
# _filter_screen time: 0:00:00.548394
# _filter_stops time: 0:00:01.109463
#
# user: 835
# _filter_call time: 0:00:00.004121
# _filter_text time: 0:00:00.006057
# _filter_physical time: 0:00:00.552089
# _filter_screen time: 0:00:00.383344
# _filter_stops time: 0:00:01.100989
#
# user: 836
# _filter_call time: 0:00:00.002144
# _filter_text time: 0:00:00.013889
# _filter_physical time: 0:00:00.581527
# _filter_screen time: 0:00:00.988559
# _filter_stops time: 0:00:01.103148
#
# user: 837
# _filter_call time: 0:00:00.002133
# _filter_text time: 0:00:00.003128
# _filter_physical time: 0:00:00.538502
# _filter_screen time: 0:00:00.057527
# _filter_stops time: 0:00:01.074561
#
# user: 838
# _filter_call time: 0:00:00.002416
# _filter_text time: 0:00:00.006029
# _filter_physical time: 0:00:00.549433
# _filter_screen time: 0:00:00.142726
# _filter_stops time: 0:00:01.083231
#
# user: 839
# _filter_call time: 0:00:00.005470
# _filter_text time: 0:00:00.009501
# _filter_physical time: 0:00:00.567326
# _filter_screen time: 0:00:00.261202
# _filter_stops time: 0:00:01.121271
#
# user: 840
# _filter_call time: 0:00:00.004451
# _filter_text time: 0:00:00.016056
# _filter_physical time: 0:00:00.539110
# _filter_screen time: 0:00:00.445007
# _filter_stops time: 0:00:01.100185
#
# user: 841
# _filter_call time: 0:00:00.003314
# _filter_text time: 0:00:00.003724
# _filter_physical time: 0:00:00.536073
# _filter_screen time: 0:00:00.004993
# _filter_stops Failed: 841
#
# user: 842
# _filter_call time: 0:00:00.004106
# _filter_text time: 0:00:00.005413
# _filter_physical time: 0:00:00.544028
# _filter_screen time: 0:00:00.086811
# _filter_stops time: 0:00:01.079727
#
# user: 843
# _filter_call time: 0:00:00.005408
# _filter_text time: 0:00:00.007534
# _filter_physical time: 0:00:00.543807
# _filter_screen time: 0:00:00.247874
# _filter_stops time: 0:00:01.099932
#
# user: 844
# _filter_call time: 0:00:00.003531
# _filter_text time: 0:00:00.033099
# _filter_physical time: 0:00:00.558440
# _filter_screen time: 0:00:01.211500
# _filter_stops time: 0:00:01.121846
#
# user: 845
# _filter_call time: 0:00:00.003822
# _filter_text time: 0:00:00.005877
# _filter_physical time: 0:00:00.546433
# _filter_screen time: 0:00:00.319072
# _filter_stops time: 0:00:01.111095
#
# user: 847
# _filter_call time: 0:00:00.005453
# _filter_text time: 0:00:00.018395
# _filter_physical time: 0:00:00.573078
# _filter_screen time: 0:00:00.834259
# _filter_stops time: 0:00:01.107555
#
# user: 848
# _filter_call time: 0:00:00.004949
# _filter_text time: 0:00:00.013620
# _filter_physical time: 0:00:00.535806
# _filter_screen time: 0:00:00.040708
# _filter_stops time: 0:00:01.077094

# %% [markdown]
# # Build dataset for science competition

# %%
from build_dataset.workers import load_sensible_data as lsd

# %%
tc0 = {'hours': range(24),
    'days': range(7),
    'spans': [
        ("03/02/14", "10/02/14")
    ]
}

# %%
dataset = lsd.load(tc0, "bluetooth", filtering="bt_special", load_cached=False)
# Out:
# <2014> feb

# %%
ds = dataset.sort_values(by="timestamp")
ds = ds.loc[dataset['bt_mac'] >= 0]
#ds['timestamp'] = ds['timestamp'] - min(ds['timestamp'])
#ds['user1'] = ds['user']
#ds['user2'] = ds['bt_mac']
#ds = ds.drop(['class', 'id', 'rssi', 'bt_mac', 'user'], axis=1)
#ds = ds[['user1', 'user2', 'timestamp']]
#csv = ds.to_csv("data_sample_science_comp_2016.csv", index=False, sep=",")

# %%
min(ds['timestamp'])%86400
# Out:
# 0.0
