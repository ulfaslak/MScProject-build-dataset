# %% [markdown]
# ### Raw data

# %%
"""Run all functions that load and cache data from remote."""

from build_dataset.workers import load_sensible_data as lsd


tc0 = {'hours': range(24),
    'days': range(7),
    'spans': [
        ("01/01/14", "31/12/14")
    ]
}
tc1 = {  # School weeks spring and fall 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("06/01/14", "25/01/14"),
        ("03/02/14", "12/04/14"),
        ("20/04/14", "17/05/14"),
        ("02/06/14", "21/06/14"),
        ("01/09/14", "11/10/14"),
        ("19/10/14", "06/12/14")
    ]
}
tc1_spring = {  # School weeks spring 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("06/01/14", "25/01/14"),
        ("03/02/14", "12/04/14"),
        ("20/04/14", "17/05/14"),
        ("02/06/14", "21/06/14"),
    ]
}
tc2 = {  # Exam weeks spring and fall 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("17/05/14", "02/06/14"),
        ("06/12/14", "22/12/14")
    ]
}
tc3 = {  # Holiday weeks spring and fall 2014
    'hours': range(24),
    'days': range(7),
    'spans': [
        ("01/01/14", "06/01/14"),
        ("25/01/14", "03/02/14"),
        ("12/04/14", "21/04/14"),
        ("21/06/14", "01/09/14"),
        ("11/10/14", "19/10/14"),
        ("22/12/14", "31/12/14")
    ]
}

for i, tc in enumerate([tc0]): #enumerate([tc0, tc1, tc1_spring, tc2, tc3]):
    print "\n\n## ---------------- ##"
    print "## Building for tc%d ##" % i
    print "## ---------------- ##"

    print "\nLocation Reference..."
    print "\nsuccess!\n"
    print "Timezone Reference..."
    print "\nsuccess!\n"

    print "Iterating over datasets:"
    for dataset in ["calllog", "sms", "screen", "stop_locations", "bluetooth"]:
        print "\tBuilding '%s'...\t\t" % dataset,
        if dataset == "bluetooth":
            lsd.load(tc, dataset, filtering="bt_special", load_cached=True)
        else:
            lsd.load(tc, dataset, load_cached=True)
        print "\n\tsuccess!\n"
# Out:
# ## ---------------- ##
# ## Building for tc0 ##
# ## ---------------- ##
#
# Location Reference...
#
# success!
#
# Timezone Reference...
#
# success!
#
# Iterating over datasets:
# 	Building 'calllog'...
# 	success!
#
# 	Building 'sms'...
# 	success!
#
# 	Building 'screen'...
# 	success!
#
# 	Building 'stop_locations'...
# 	success!
#
# 	Building 'bluetooth'...
# 	success!

# %% [markdown]
# ### Records

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from collections import Counter
import os
from build_dataset.workers import load_sensible_data as lsd
from build_dataset.analysis import location_reference as locref

tc = tc0
tc_str = "tc0"

location_reference_tc = locref.Load_location_reference(tc).location_reference

df_call = lsd.load(tc, "calllog")
df_text = lsd.load(tc, "sms")
df_screen = lsd.load(tc, "screen")
df_stops = lsd.load(tc, "stop_locations")
df_physical = lsd.load(tc, "bluetooth")

users = set(list(df_call['user'])) & set(list(df_text['user'])) & set(list(df_screen['user'])) & \
        set(list(df_stops['user'])) & set(list(df_physical['user']))
    
def call_timer(func):
    """Simple decorator to time function calls."""
    def wrapper(*args):
        print func.__name__,
        start = dt.now()
        output = func(*args)
        print "time:", dt.now() - start
        return output
    return wrapper
    
@call_timer
def _filter_call(df_u):
    df_u = df_u.drop('user', 1)
    df_u.loc[:, 'interaction'] = "call"
    df_u.loc[:, 'timestamp'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'timestamp']]
    df_u.loc[:, 'type'] = ["in" if t == 1 else "out" for t in df_u.loc[:, 'type']]
    df_u.columns = ["duration", "correspondent_id", "datetime", "direction", "interaction"]
    return df_u

@call_timer
def _filter_text(df_u):
    df_u = df_u[df_u.loc[:, 'status'] <= 0]
    df_u = df_u[df_u.loc[:, 'type'] <= 2]
    df_u = df_u.drop(['status','user'], 1)
    df_u.loc[:, 'interaction'] = 'text'
    df_u.loc[:, 'timestamp'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'timestamp']]
    df_u.loc[:, 'type'] = ["in" if t == 1 else "out" for t in df_u.loc[:, 'type']]
    df_u.columns = ["correspondent_id", "datetime", "direction", "interaction"]
    return df_u

@call_timer
def _filter_physical(u, df_u):
    df_u.loc[:, 'interaction'] = 'physical'
    df_u.loc[:, 'timestamp'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'timestamp']]
    df_u.loc[:, 'correspondent_id'] = [a if a != u else b 
                                for a,b in zip(df_u.loc[:, 'bt_mac'], df_u.loc[:, 'user'])]
    df_u = df_u.drop(['class','id','bt_mac','rssi', 'user'], 1)
    df_u.columns = ["datetime", "interaction", "correspondent_id"]
    return df_u

@call_timer
def _filter_screen(df_u):
    sessions = []
    i = 0
    for row in df_u.iterrows():
        event, times = row[1]['screen_on'], row[1]['timestamp']
        if i == 0:
            prev_event = event
            prev_times = times
            i+=1; continue
        elif event == 0 and prev_event == 1:
            duration = int(times-prev_times)
            sessions.append({'datetime': dt.fromtimestamp(prev_times), 
                             'duration': duration})
        prev_event = event
        prev_times = times
        i+=1
    df_u = pd.DataFrame(sessions)
    df_u.loc[:, 'interaction'] = 'screen'
    return df_u

@call_timer
def _filter_stops(u, df_u):
    def evaluate_event(r):
        user, label, arrival, departure = \
        r[1]['user'], r[1]['label'], r[1]['arrival'], r[1]['departure']
        
        state = location_reference_tc[str(user)][str(label)]
        if state['type'] == "home":
            return "home"
        if state['type'] == "campus":
            if state['__friday_bar'] and dt.fromtimestamp(np.mean([arrival,departure])).hour >=17:
                return "friday_bar"
            return "campus"
        return "other"
        
    df_u.loc[:, 'duration'] = df_u.loc[:, 'departure'] - df_u.loc[:, 'arrival']
    df_u.loc[:, 'datetime'] = [dt.fromtimestamp(t) for t in df_u.loc[:, 'arrival']]
    df_u.loc[:, 'position'] = ["%d_%s" % (u, l) for l in df_u.loc[:, 'label']]
    df_u.loc[:, 'event'] = [evaluate_event(r) for r in df_u.iterrows()]
    df_u.loc[:, 'interaction'] = 'stop'
    df_u = df_u.drop(['arrival', 'departure', 'label', 'lat', 'lon', 'timestamp', 'user'], 1)
    return df_u


def processed_users(tc):
    interaction_types = ["call", "text", "physical", "screen", "stop"]
    counter = Counter()
    for t in interaction_types:
        users = [int(f.split(".")[0]) for f in os.listdir("build_dataset/data_cache/records/%s/%s" % (t, tc))]
        counter.update(users)
    return [k for k,v in counter.items() if v == 5]
    
skip_users = []# processed_users(tc_str)
for u in users:
    
    if u in skip_users:
        continue
    
    print "\nuser:", u
    try:
        df_call_u = _filter_call(df_call[df_call.loc[:, 'user'] == u])
        df_text_u = _filter_text(df_text[df_text.loc[:, 'user'] == u])
        df_physical_u = _filter_physical(u, df_physical.loc[(df_physical.loc[:, 'user'] == u) | \
                                                            (df_physical.loc[:, 'bt_mac'] == u), :])
        df_screen_u = _filter_screen(df_screen[df_screen.loc[:, 'user'] == u])
        df_stop_u = _filter_stops(u, df_stops[df_stops.loc[:, 'user'] == u])
    
        df_call_u.to_csv("build_dataset/data_cache/records/call/%s/%d.csv" % (tc_str, u), index=False)
        df_text_u.to_csv("build_dataset/data_cache/records/text/%s/%d.csv" % (tc_str, u), index=False)
        df_physical_u.to_csv("build_dataset/data_cache/records/physical/%s/%d.csv" % (tc_str, u), index=False)
        df_screen_u.to_csv("build_dataset/data_cache/records/screen/%s/%d.csv" % (tc_str, u), index=False)
        df_stop_u.to_csv("build_dataset/data_cache/records/stop/%s/%d.csv" % (tc_str, u), index=False)
    except:
        print "Failed:", u
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# user: 0
# _filter_call time: 0:00:00.008323
# _filter_text time: 0:00:00.021579
# _filter_physical time: 0:00:00.671981
# _filter_screen time: 0:00:02.274172
# _filter_stops time: 0:00:01.223384
#
# user: 1
# _filter_call time: 0:00:00.002560
# _filter_text time: 0:00:00.004838
# _filter_physical time: 0:00:00.593258
# _filter_screen time: 0:00:00.299630
# _filter_stops time: 0:00:01.159969
#
# user: 2
# _filter_call time: 0:00:00.002747
# _filter_text time: 0:00:00.015357
# _filter_physical time: 0:00:00.564644
# _filter_screen time: 0:00:00.418994
# _filter_stops time: 0:00:01.142865
#
# user: 3
# _filter_call time: 0:00:00.005587
# _filter_text time: 0:00:00.026617
# _filter_physical time: 0:00:00.606946
# _filter_screen time: 0:00:01.462182
# _filter_stops time: 0:00:01.189190
#
# user: 4
# _filter_call time: 0:00:00.007425
# _filter_text time: 0:00:00.016716
# _filter_physical time: 0:00:00.606882
# _filter_screen time: 0:00:00.957388
# _filter_stops time: 0:00:01.181318
#
# user: 5
# _filter_call time: 0:00:00.005712
# _filter_text time: 0:00:00.074484
# _filter_physical time: 0:00:00.619240
# _filter_screen time: 0:00:02.034072
# _filter_stops time: 0:00:01.222255
#
# user: 6
# _filter_call time: 0:00:00.007888
# _filter_text time: 0:00:00.033906
# _filter_physical time: 0:00:00.661342
# _filter_screen time: 0:00:00.808781
# _filter_stops time: 0:00:01.178726
#
# user: 7
# _filter_call time: 0:00:00.004418
# _filter_text time: 0:00:00.006941
# _filter_physical time: 0:00:00.598094
# _filter_screen time: 0:00:00.617002
# _filter_stops time: 0:00:01.154474
#
# user: 8
# _filter_call time: 0:00:00.003087
# _filter_text time: 0:00:00.005418
# _filter_physical time: 0:00:00.661510
# _filter_screen time: 0:00:00.629807
# _filter_stops time: 0:00:01.164091
#
# user: 9
# _filter_call time: 0:00:00.003638
# _filter_text time: 0:00:00.003023
# _filter_physical time: 0:00:00.559689
# _filter_screen time: 0:00:00.166753
# _filter_stops time: 0:00:01.121828
#
# user: 10
# _filter_call time: 0:00:00.006784
# _filter_text time: 0:00:00.018721
# _filter_physical time: 0:00:00.579220
# _filter_screen time: 0:00:01.054146
# _filter_stops time: 0:00:01.204999
#
# user: 11
# _filter_call time: 0:00:00.006161
# _filter_text time: 0:00:00.021402
# _filter_physical time: 0:00:00.567465
# _filter_screen time: 0:00:01.067122
# _filter_stops time: 0:00:01.163287
#
# user: 12
# _filter_call time: 0:00:00.005850
# _filter_text time: 0:00:00.022490
# _filter_physical time: 0:00:00.693856
# _filter_screen time: 0:00:02.681818
# _filter_stops time: 0:00:01.204321
#
# user: 13
# _filter_call time: 0:00:00.004511
# _filter_text time: 0:00:00.016280
# _filter_physical time: 0:00:00.643385
# _filter_screen time: 0:00:01.111203
# _filter_stops time: 0:00:01.168414
#
# user: 14
# _filter_call time: 0:00:00.003184
# _filter_text time: 0:00:00.013608
# _filter_physical time: 0:00:00.580839
# _filter_screen time: 0:00:00.541043
# _filter_stops time: 0:00:01.160463
#
# user: 15
# _filter_call time: 0:00:00.007554
# _filter_text time: 0:00:00.010242
# _filter_physical time: 0:00:00.692093
# _filter_screen time: 0:00:00.821399
# _filter_stops time: 0:00:01.208485
#
# user: 16
# _filter_call time: 0:00:00.002557
# _filter_text time: 0:00:00.003663
# _filter_physical time: 0:00:00.591634
# _filter_screen time: 0:00:00.201582
# _filter_stops time: 0:00:01.132921
#
# user: 17
# _filter_call time: 0:00:00.005339
# _filter_text time: 0:00:00.007006
# _filter_physical time: 0:00:00.578409
# _filter_screen time: 0:00:01.285214
# _filter_stops time: 0:00:01.190986
#
# user: 18
# _filter_call time: 0:00:00.033200
# _filter_text time: 0:00:00.024138
# _filter_physical time: 0:00:00.594097
# _filter_screen time: 0:00:01.037866
# _filter_stops time: 0:00:01.220482
#
# user: 19
# _filter_call time: 0:00:00.010879
# _filter_text time: 0:00:00.016368
# _filter_physical time: 0:00:00.570105
# _filter_screen time: 0:00:01.841879
# _filter_stops time: 0:00:01.201012
#
# user: 20
# _filter_call time: 0:00:00.003635
# _filter_text time: 0:00:00.014441
# _filter_physical time: 0:00:00.590509
# _filter_screen time: 0:00:00.407063
# _filter_stops time: 0:00:01.135294
#
# user: 21
# _filter_call time: 0:00:00.005213
# _filter_text time: 0:00:00.029217
# _filter_physical time: 0:00:00.589830
# _filter_screen time: 0:00:01.539305
# _filter_stops time: 0:00:01.156407
#
# user: 22
# _filter_call time: 0:00:00.007713
# _filter_text time: 0:00:00.012985
# _filter_physical time: 0:00:00.592134
# _filter_screen time: 0:00:00.581723
# _filter_stops time: 0:00:01.122184
#
# user: 23
# _filter_call time: 0:00:00.006692
# _filter_text time: 0:00:00.080680
# _filter_physical time: 0:00:00.587333
# _filter_screen time: 0:00:01.462019
# _filter_stops time: 0:00:01.152952
#
# user: 24
# _filter_call time: 0:00:00.012256
# _filter_text time: 0:00:00.110808
# _filter_physical time: 0:00:00.561713
# _filter_screen time: 0:00:01.172603
# _filter_stops time: 0:00:01.159194
#
# user: 25
# _filter_call time: 0:00:00.004988
# _filter_text time: 0:00:00.002917
# _filter_physical time: 0:00:00.630820
# _filter_screen time: 0:00:00.963079
# _filter_stops time: 0:00:01.184971
#
# user: 26
# _filter_call time: 0:00:00.002782
# _filter_text time: 0:00:00.004475
# _filter_physical time: 0:00:00.589684
# _filter_screen time: 0:00:00.133627
# _filter_stops time: 0:00:01.169402
#
# user: 27
# _filter_call time: 0:00:00.005805
# _filter_text time: 0:00:00.013360
# _filter_physical time: 0:00:00.624683
# _filter_screen time: 0:00:00.718956
# _filter_stops time: 0:00:01.220337
#
# user: 28
# _filter_call time: 0:00:00.006271
# _filter_text time: 0:00:00.008366
# _filter_physical time: 0:00:00.570458
# _filter_screen time: 0:00:00.499239
# _filter_stops time: 0:00:01.138010
#
# user: 29
# _filter_call time: 0:00:00.008310
# _filter_text time: 0:00:00.017199
# _filter_physical time: 0:00:00.590751
# _filter_screen time: 0:00:00.423307
# _filter_stops time: 0:00:01.171441
#
# user: 30
# _filter_call time: 0:00:00.008676
# _filter_text time: 0:00:00.012476
# _filter_physical time: 0:00:00.600031
# _filter_screen time: 0:00:02.205061
# _filter_stops time: 0:00:01.202243
#
# user: 31
# _filter_call time: 0:00:00.005422
# _filter_text time: 0:00:00.033548
# _filter_physical time: 0:00:00.596307
# _filter_screen time: 0:00:00.854201
# _filter_stops time: 0:00:01.179225
#
# user: 32
# _filter_call time: 0:00:00.004544
# _filter_text time: 0:00:00.006051
# _filter_physical time: 0:00:00.590571
# _filter_screen

# %% [markdown]
# # Build dataset for science competition

# %%
from build_dataset.workers import load_sensible_data as lsd

# %%
tc0 = {'hours': range(24),
    'days': range(7),
    'spans': [
        ("03/02/14", "10/02/14")
    ]
}

# %%
dataset = lsd.load(tc0, "bluetooth", filtering="bt_special", load_cached=False)
# Out:
# <2014> feb

# %%
ds = dataset.sort_values(by="timestamp")
ds = ds.loc[dataset['bt_mac'] >= 0]
#ds['timestamp'] = ds['timestamp'] - min(ds['timestamp'])
#ds['user1'] = ds['user']
#ds['user2'] = ds['bt_mac']
#ds = ds.drop(['class', 'id', 'rssi', 'bt_mac', 'user'], axis=1)
#ds = ds[['user1', 'user2', 'timestamp']]
#csv = ds.to_csv("data_sample_science_comp_2016.csv", index=False, sep=",")

# %%
min(ds['timestamp'])%86400
# Out:
# 0.0
