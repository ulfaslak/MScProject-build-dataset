# %%
from sensible_raw.loaders import loader

# %%
columns, data = loader.load_data("stop_locations", "january_2015")

# %%
data[1].nbytes
# Out:
# 282648

# %%
loader.get_raw_value("user", 58)
# Out:
# '0037c93a19a7e90580086b462ba11b'

# %%
columns
# Out:
# [u'user', u'timestamp', u'lat', u'lon', u'label', u'arrival', u'departure']

# %%
import pandas

dict = {}
for column, array in zip(columns, data):
    dict[column] = array
dataframe = pandas.DataFrame(dict)

# %%
dataframe
# Out:
#           arrival   departure  label        lat        lon      timestamp  \
# 0      1420080300  1420081200    259  57.048504   9.922209  1420083900000
# 1      1420083000  1420084800    180  57.042887   9.919762  1420086600000
# 2      1420086600  1420087500    100  57.043881   9.917559  1420090200000
# 3      1420091100  1420205400      9  57.481213   9.973468  1420094700000
# 4      1420207200  1420208100     13  57.457599   9.991723  1420210800000
# 5      1420211700  1420214400      9  57.481211   9.973469  1420215300000
# 6      1420217100  1420245900    186  57.340319  10.236575  1420220700000
# 7      1420248600  1420295400      9  57.481211   9.973471  1420252200000
# 8      1420318800  1420373700      1  55.788440  12.531809  1420322400000
# 9      1420375500  1420447500      1  55.788445  12.531808  1420379100000
# 10     1420449300  1420454700      5  55.786751  12.523309  1420452900000
# 11     1420455600  1420457400      5  55.786524  12.524033  1420459200000
# ...
